# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
import matplotlib.pyplot as plt

class CustomDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')], key=lambda x: int(x.split('_')[1].split('.')[0]))
        self.transform = transform

    def __len__(self):
        return len(self.image_files) - 1  # Subtract 1 because the last image has no next image

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir, self.image_files[idx])
        next_img_name = os.path.join(self.image_dir, self.image_files[idx + 1])
        
        image = Image.open(img_name).convert('L')  # Convert image to grayscale
        next_image = Image.open(next_img_name).convert('L')  # Convert next image to grayscale
        
        if self.transform:
            image = self.transform(image)
            next_image = self.transform(next_image)
        
        return image, next_image

# Define the directory where images are stored
image_dir = 'images_10000'

# Define transformations (if any)
transform = transforms.Compose([
    transforms.ToTensor()
])

# Create the dataset
dataset = CustomDataset(image_dir=image_dir, transform=transform)

# Print the length of the dataset
print(f"Total dataset length: {len(dataset)}")

# Calculate lengths for train, val, test datasets
total_len = len(dataset)
train_len = int(0.6 * total_len)
val_len = int(0.2 * total_len)
test_len = total_len - train_len - val_len

# Print the lengths of the train, val, and test datasets
print(f"Train dataset length: {train_len}")
print(f"Validation dataset length: {val_len}")
print(f"Test dataset length: {test_len}")

# Create subsets manually by indices
train_indices = list(range(0, train_len))
val_indices = list(range(train_len, train_len + val_len))
test_indices = list(range(train_len + val_len, total_len))

train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Function to display images
def show_images(images, nrow=1, ncol=5):
    fig, axes = plt.subplots(nrow, ncol, figsize=(15, 3))
    for i in range(ncol):
        ax = axes[i]
        ax.imshow(images[i].squeeze(), cmap='gray')
        ax.axis('off')
    plt.show()

# Display the first five pairs of images in the dataset
if __name__ == '__main__':
    # Display the first five pairs of images
    first_five_pairs = [dataset[i] for i in range(5)]
    first_images = [pair[0] for pair in first_five_pairs]
    next_images = [pair[1] for pair in first_five_pairs]
    
    print("First images:")
    show_images(first_images)
    
    print("Next images:")
    show_images(next_images)
    
    # Example usage of data loaders
    for images, targets in train_loader:
        print(images.size(), targets.size())  # Example output: torch.Size([64, 1, H, W]) torch.Size([64, 1, H, W])
        break
# Out:
# Total dataset length: 9999
# Train dataset length: 5999
# Validation dataset length: 1999
# Test dataset length: 2001
# First images:
# Next images:
# torch.Size([16, 1, 64, 64]) torch.Size([16, 1, 64, 64])

# %%
import torch
import torch.nn as nn

class SimpleLinearNetwork(nn.Module):
    def __init__(self):
        super(SimpleLinearNetwork, self).__init__()
        self.flatten = nn.Flatten()  # 将输入展平
        self.linear = nn.Linear(64 * 64, 256)  # 一个线性层

    def forward(self, x):
        x = self.flatten(x)  # 展平输入
        x = self.linear(x)  # 线性层变换
        return x

# 示例张量 (B, 1, 64, 64)
input_tensor = torch.randn(8, 1, 64, 64)  # 这里 B = 8 作为示例

# 创建网络实例
model = SimpleLinearNetwork()

# 前向传播
output_tensor = model(input_tensor)
print(output_tensor.shape)  # 期望输出 (B, 256)，这里 B = 8
# Out:
# torch.Size([8, 256])

# %%
import torch
import torch.nn as nn

class Time2Vec(nn.Module):
    def __init__(self, seq_len):
        super(Time2Vec, self).__init__()
        self.seq_len = seq_len
        self.weights_linear = nn.Parameter(torch.Tensor(seq_len // 2))
        self.bias_linear = nn.Parameter(torch.Tensor(seq_len // 2))
        self.weights_periodic = nn.Parameter(torch.Tensor(seq_len // 2))
        self.bias_periodic = nn.Parameter(torch.Tensor(seq_len // 2))
        self.reset_parameters()

    def reset_parameters(self):
        nn.init.uniform_(self.weights_linear)
        nn.init.uniform_(self.bias_linear)
        nn.init.uniform_(self.weights_periodic)
        nn.init.uniform_(self.bias_periodic)

    def forward(self, x):
        x_mean = torch.mean(x, dim=-1, keepdim=True)  # (B, 256) -> (B, 1)
        
        # 线性时间嵌入
        time_linear = self.weights_linear * x_mean + self.bias_linear  # (B, 1) -> (B, 128)
        
        # 周期性时间嵌入
        time_periodic = torch.sin(self.weights_periodic * x_mean + self.bias_periodic)  # (B, 1) -> (B, 128)
        
        # 拼接线性和周期性时间嵌入
        time_embedding = torch.cat([time_linear, time_periodic], dim=-1)  # (B, 128) and (B, 128) -> (B, 256)
        
        # 残差连接，将输入x与时间嵌入拼接
        residual_connection = torch.cat([x, time_embedding], dim=-1)  # (B, 256) and (B, 256) -> (B, 512)
        
        return residual_connection

# 示例用法
input_tensor = torch.randn(32, 256)  # (B, 256)
model = Time2Vec(seq_len=256)
output_tensor = model(input_tensor)  # (B, 512)

print(output_tensor.shape)  # 应输出: torch.Size([32, 512])
# Out:
# torch.Size([32, 512])

# %%
import torch
import torch.nn as nn

class SingleAttentionHead(nn.Module):
    def __init__(self, input_dim, d_k, d_v):
        super(SingleAttentionHead, self).__init__()
        self.d_k = d_k
        self.d_v = d_v

        self.W_Q = nn.Linear(input_dim, d_k)  # (input_dim, d_k)
        self.W_K = nn.Linear(input_dim, d_k)  # (input_dim, d_k)
        self.W_V = nn.Linear(input_dim, d_v)  # (input_dim, d_v)
        self.softmax = nn.Softmax(dim=-1)  # 使用 nn.Softmax

    def forward(self, X):
        # X: (B, input_dim)
        Q = self.W_Q(X)  # (B, d_k)
        K = self.W_K(X)  # (B, d_k)
        V = self.W_V(X)  # (B, d_v)

        # scores: (B, B)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / torch.sqrt(torch.tensor(self.d_k, dtype=torch.float32))  
        
        # attention_weights: (B, B)
        attention_weights = self.softmax(scores)
        
        # attention_output: (B, d_v)
        attention_output = torch.matmul(attention_weights, V)  

        return attention_output

# 示例使用
B = 32  # 批次大小
input_dim = 512  # 输入维度
d_k = 64
d_v = 128

# 随机生成输入张量
X = torch.randn(B, input_dim)

# 创建注意力头实例
attention_head = SingleAttentionHead(input_dim, d_k, d_v)

# 前向传播
output = attention_head(X)

print("Attention Output Shape:", output.shape)  # 输出应为 (B, d_v)
# Out:
# Attention Output Shape: torch.Size([32, 128])

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, input_dim, num_heads, d_k, d_v):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_k = d_k
        self.d_v = d_v

        # 创建多个注意力头，每个注意力头都是一个SingleAttentionHead实例
        self.attention_heads = nn.ModuleList([SingleAttentionHead(input_dim, d_k, d_v) for _ in range(num_heads)])
        self.W_O = nn.Linear(num_heads * d_v, input_dim)  # (num_heads * d_v, input_dim)


    def forward(self, X):
        # X: (B, input_dim)
        
        # 获取所有头的注意力输出，列表中的每个元素形状为 (B, d_v)
        attention_outputs = [head(X) for head in self.attention_heads]
        
        # 拼接所有头的输出，结果形状为 (B, num_heads * d_v)
        concat_output = torch.cat(attention_outputs, dim=-1)
        
        # 通过线性变换，最终输出形状为 (B, input_dim)
        output = self.W_O(concat_output)
        
        return output

# 示例使用
B = 32  # 批次大小
input_dim = 512  # 输入维度
num_heads = 32  # 头的数量
d_k = 64
d_v = 128

# 随机生成输入张量
X = torch.randn(B, input_dim)

# 创建多头注意力实例
multi_head_attention = MultiHeadAttention(input_dim, num_heads, d_k, d_v)

# 前向传播
output = multi_head_attention(X)

print("Multi-Head Attention Output Shape:", output.shape)  # 输出应为 (B, input_dim)
# Out:
# Multi-Head Attention Output Shape: torch.Size([32, 512])

# %%
import torch
import torch.nn as nn

class ProcessingModule(nn.Module):
    def __init__(self, input_dim=512, hidden_dim=2048, dropout_rate=0.1):
        super(ProcessingModule, self).__init__()
        self.dropout = nn.Dropout(dropout_rate)
        self.norm1 = nn.LayerNorm(input_dim)
        self.feed_forward = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )
        self.norm2 = nn.LayerNorm(input_dim)

    def forward(self, x):
        # Residual connection around dropout and normalization
        residual = x
        x = self.dropout(x)
        x = self.norm1(x + residual)
        
        # Feed-forward network
        x = self.feed_forward(x)
        
        # Add residual connection and apply final normalization
        x = self.norm2(x + residual)
        
        return x

# Example usage
batch_size = 32  # Example batch size
input_tensor = torch.randn((batch_size, 512))  # replace batch_size with your batch size
model = ProcessingModule()
output = model(input_tensor)

print("Output shape:", output.shape)  # Print output shape
# Out:
# Output shape: torch.Size([32, 512])

# %%
class CombinedNetwork(nn.Module):
    def __init__(self, seq_len, input_dim, num_heads, d_k, d_v):
        super(CombinedNetwork, self).__init__()
        
        self.encoder = nn.Sequential(
            SimpleLinearNetwork(),
            Time2Vec(seq_len),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim)
        )
        
        self.latent = nn.Sequential(
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim)
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(512, 64 * 8 * 8),  # (B, 512) -> (B, 64*8*8)
            nn.Unflatten(1, (64, 8, 8)),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 64, 8, 8) -> (B, 32, 16, 16)
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 32, 16, 16) -> (B, 16, 32, 32)
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 16, 32, 32) -> (B, 1, 64, 64)
            nn.Sigmoid()  # Ensure the output values are between 0 and 1
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.latent(x)
        x = self.decoder(x)
        return x

# 示例使用
seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

model = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v)
sample_input = torch.randn((32, 1, 64, 64))  # 假设输入是32个64x64的单通道图像
output = model(sample_input)
print(output.shape)  # 输出形状
# Out:
# torch.Size([32, 1, 64, 64])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

# Initialize the autoencoder, loss function and optimizer
autoencoder = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v).to(device)

# Load pretrained weights for encoder and decoder
autoencoder.encoder.load_state_dict(torch.load('best_encoder_2.pth'))
autoencoder.decoder.load_state_dict(torch.load('best_decoder_2.pth'))

# Freeze encoder and decoder
for param in autoencoder.encoder.parameters():
    param.requires_grad = False

for param in autoencoder.decoder.parameters():
    param.requires_grad = False

criterion = nn.MSELoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, autoencoder.parameters()), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

# Early stopping class
class EarlyStopping:
    def __init__(self, patience=20, verbose=False, delta=0, path='checkpoint.pth'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# Function to save the model
def save_model(model, path):
    torch.save(model.state_dict(), path)

# Training function
def train_autoencoder(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience=20):
    early_stopping = EarlyStopping(patience=patience, verbose=True, path='best_model_3_2_1.pth')
    model.train()

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        avg_train_loss = running_loss / len(train_loader)

        # Validation step
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
        
        avg_val_loss = val_loss / len(val_loader)
        
        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
        
        # Adjust learning rate based on validation loss
        scheduler.step(avg_val_loss)

        # Check early stopping condition
        early_stopping(avg_val_loss, model)

        if early_stopping.early_stop:
            print("Early stopping")
            break

    # Load the best model
    model.load_state_dict(torch.load('best_model_3_2_1.pth'))
    
    # Print the best validation loss
    print(f'Best Validation Loss: {early_stopping.val_loss_min:.4f}')
    
    return model

# Evaluation function
def evaluate_autoencoder(model, dataloader):
    model.eval()
    original_images = []
    reconstructed_images = []
    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            original_images.extend(targets.cpu())
            reconstructed_images.extend(outputs.cpu())
            break  # Remove this line if you want to evaluate the whole dataset
    return original_images, reconstructed_images

# Assume train_loader, val_loader, and test_loader are defined and loaded elsewhere

# Train the autoencoder with early stopping
autoencoder = train_autoencoder(autoencoder, train_loader, val_loader, criterion, optimizer, scheduler, epochs=10000, patience=20)

# Evaluate the autoencoder
original_images, reconstructed_images = evaluate_autoencoder(autoencoder, test_loader)
# Out:
# Using device: cuda
# Epoch [1/10000], Train Loss: 0.0614, Val Loss: 0.0332
# Validation loss decreased (inf --> 0.033248).  Saving model ...
# Epoch [2/10000], Train Loss: 0.0321, Val Loss: 0.0309
# Validation loss decreased (0.033248 --> 0.030946).  Saving model ...
# Epoch [3/10000], Train Loss: 0.0311, Val Loss: 0.0306
# Validation loss decreased (0.030946 --> 0.030603).  Saving model ...
# Epoch [4/10000], Train Loss: 0.0305, Val Loss: 0.0300
# Validation loss decreased (0.030603 --> 0.029974).  Saving model ...
# Epoch [5/10000], Train Loss: 0.0301, Val Loss: 0.0301
# EarlyStopping counter: 1 out of 20
# Epoch [6/10000], Train Loss: 0.0301, Val Loss: 0.0297
# Validation loss decreased (0.029974 --> 0.029704).  Saving model ...
# Epoch [7/10000], Train Loss: 0.0297, Val Loss: 0.0297
# Validation loss decreased (0.029704 --> 0.029663).  Saving model ...
# Epoch [8/10000], Train Loss: 0.0296, Val Loss: 0.0293
# Validation loss decreased (0.029663 --> 0.029311).  Saving model ...
# Epoch [9/10000], Train Loss: 0.0293, Val Loss: 0.0292
# Validation loss decreased (0.029311 --> 0.029156).  Saving model ...
# Epoch [10/10000], Train Loss: 0.0294, Val Loss: 0.0291
# Validation loss decreased (0.029156 --> 0.029053).  Saving model ...
# Epoch [11/10000], Train Loss: 0.0293, Val Loss: 0.0295
# EarlyStopping counter: 1 out of 20
# Epoch [12/10000], Train Loss: 0.0294, Val Loss: 0.0298
# EarlyStopping counter: 2 out of 20
# Epoch [13/10000], Train Loss: 0.0297, Val Loss: 0.0297
# EarlyStopping counter: 3 out of 20
# Epoch [14/10000], Train Loss: 0.0294, Val Loss: 0.0296
# EarlyStopping counter: 4 out of 20
# Epoch [15/10000], Train Loss: 0.0294, Val Loss: 0.0292
# EarlyStopping counter: 5 out of 20
# Epoch [16/10000], Train Loss: 0.0294, Val Loss: 0.0290
# Validation loss decreased (0.029053 --> 0.029031).  Saving model ...
# Epoch [17/10000], Train Loss: 0.0292, Val Loss: 0.0291
# EarlyStopping counter: 1 out of 20
# Epoch [18/10000], Train Loss: 0.0292, Val Loss: 0.0289
# Validation loss decreased (0.029031 --> 0.028908).  Saving model ...
# Epoch [19/10000], Train Loss: 0.0291, Val Loss: 0.0290
# EarlyStopping counter: 1 out of 20
# Epoch [20/10000], Train Loss: 0.0290, Val Loss: 0.0289
# Validation loss decreased (0.028908 --> 0.028908).  Saving model ...
# Epoch [21/10000], Train Loss: 0.0289, Val Loss: 0.0286
# Validation loss decreased (0.028908 --> 0.028560).  Saving model ...
# Epoch [22/10000], Train Loss: 0.0288, Val Loss: 0.0287
# EarlyStopping counter: 1 out of 20
# Epoch [23/10000], Train Loss: 0.0289, Val Loss: 0.0289
# EarlyStopping counter: 2 out of 20
# Epoch [24/10000], Train Loss: 0.0287, Val Loss: 0.0286
# EarlyStopping counter: 3 out of 20
# Epoch [25/10000], Train Loss: 0.0286, Val Loss: 0.0284
# Validation loss decreased (0.028560 --> 0.028440).  Saving model ...
# Epoch [26/10000], Train Loss: 0.0288, Val Loss: 0.0287
# EarlyStopping counter: 1 out of 20
# Epoch [27/10000], Train Loss: 0.0286, Val Loss: 0.0286
# EarlyStopping counter: 2 out of 20
# Epoch [28/10000], Train Loss: 0.0285, Val Loss: 0.0286
# EarlyStopping counter: 3 out of 20
# Epoch [29/10000], Train Loss: 0.0286, Val Loss: 0.0287
# EarlyStopping counter: 4 out of 20
# Epoch [30/10000], Train Loss: 0.0287, Val Loss: 0.0286
# EarlyStopping counter: 5 out of 20
# Epoch [31/10000], Train Loss: 0.0286, Val Loss: 0.0285
# EarlyStopping counter: 6 out of 20
# Epoch [32/10000], Train Loss: 0.0287, Val Loss: 0.0286
# EarlyStopping counter: 7 out of 20
# Epoch [33/10000], Train Loss: 0.0287, Val Loss: 0.0286
# EarlyStopping counter: 8 out of 20
# Epoch [34/10000], Train Loss: 0.0285, Val Loss: 0.0283
# Validation loss decreased (0.028440 --> 0.028332).  Saving model ...
# Epoch [35/10000], Train Loss: 0.0285, Val Loss: 0.0286
# EarlyStopping counter: 1 out of 20
# Epoch [36/10000], Train Loss: 0.0285, Val Loss: 0.0285
# EarlyStopping counter: 2 out of 20
# Epoch [37/10000], Train Loss: 0.0285, Val Loss: 0.0282
# Validation loss decreased (0.028332 --> 0.028228).  Saving model ...
# Epoch [38/10000], Train Loss: 0.0285, Val Loss: 0.0286
# EarlyStopping counter: 1 out of 20
# Epoch [39/10000], Train Loss: 0.0286, Val Loss: 0.0284
# EarlyStopping counter: 2 out of 20
# Epoch [40/10000], Train Loss: 0.0285, Val Loss: 0.0285
# EarlyStopping counter: 3 out of 20
# Epoch [41/10000], Train Loss: 0.0285, Val Loss: 0.0282
# EarlyStopping counter: 4 out of 20
# Epoch [42/10000], Train Loss: 0.0284, Val Loss: 0.0282
# Validation loss decreased (0.028228 --> 0.028210).  Saving model ...
# Epoch [43/10000], Train Loss: 0.0285, Val Loss: 0.0282
# EarlyStopping counter: 1 out of 20
# Epoch [44/10000], Train Loss: 0.0284, Val Loss: 0.0281
# Validation loss decreased (0.028210 --> 0.028087).  Saving model ...
# Epoch [45/10000], Train Loss: 0.0283, Val Loss: 0.0283
# EarlyStopping counter: 1 out of 20
# Epoch [46/10000], Train Loss: 0.0284, Val Loss: 0.0281
# EarlyStopping counter: 2 out of 20
# Epoch [47/10000], Train Loss: 0.0283, Val Loss: 0.0284
# EarlyStopping counter: 3 out of 20
# Epoch [48/10000], Train Loss: 0.0283, Val Loss: 0.0284
# EarlyStopping counter: 4 out of 20
# Epoch [49/10000], Train Loss: 0.0283, Val Loss: 0.0283
# EarlyStopping counter: 5 out of 20
# Epoch [50/10000], Train Loss: 0.0282, Val Loss: 0.0280
# Validation loss decreased (0.028087 --> 0.028049).  Saving model ...
# Epoch [51/10000], Train Loss: 0.0282, Val Loss: 0.0280
# Validation loss decreased (0.028049 --> 0.028045).  Saving model ...
# Epoch [52/10000], Train Loss: 0.0283, Val Loss: 0.0284
# EarlyStopping counter: 1 out of 20
# Epoch [53/10000], Train Loss: 0.0282, Val Loss: 0.0280
# Validation loss decreased (0.028045 --> 0.028021).  Saving model ...
# Epoch [54/10000], Train Loss: 0.0281, Val Loss: 0.0279
# Validation loss decreased (0.028021 --> 0.027915).  Saving model ...
# Epoch [55/10000], Train Loss: 0.0281, Val Loss: 0.0279
# Validation loss decreased (0.027915 --> 0.027852).  Saving model ...
# Epoch [56/10000], Train Loss: 0.0281, Val Loss: 0.0280
# EarlyStopping counter: 1 out of 20
# Epoch [57/10000], Train Loss: 0.0281, Val Loss: 0.0279
# EarlyStopping counter: 2 out of 20
# Epoch [58/10000], Train Loss: 0.0282, Val Loss: 0.0279
# EarlyStopping counter: 3 out of 20
# Epoch [59/10000], Train Loss: 0.0280, Val Loss: 0.0279
# EarlyStopping counter: 4 out of 20
# Epoch [60/10000], Train Loss: 0.0280, Val Loss: 0.0280
# EarlyStopping counter: 5 out of 20
# Epoch [61/10000], Train Loss: 0.0280, Val Loss: 0.0281
# EarlyStopping counter: 6 out of 20
# Epoch [62/10000], Train Loss: 0.0280, Val Loss: 0.0278
# Validation loss decreased (0.027852 --> 0.027836).  Saving model ...
# Epoch [63/10000], Train Loss: 0.0280, Val Loss: 0.0282
# EarlyStopping counter: 1 out of 20
# Epoch [64/10000], Train Loss: 0.0281, Val Loss: 0.0280
# EarlyStopping counter: 2 out of 20
# Epoch [65/10000], Train Loss: 0.0280, Val Loss: 0.0280
# EarlyStopping counter: 3 out of 20
# Epoch [66/10000], Train Loss: 0.0279, Val Loss: 0.0281
# EarlyStopping counter: 4 out of 20
# Epoch [67/10000], Train Loss: 0.0280, Val Loss: 0.0279
# EarlyStopping counter: 5 out of 20
# Epoch [68/10000], Train Loss: 0.0279, Val Loss: 0.0279
# EarlyStopping counter: 6 out of 20
# Epoch [69/10000], Train Loss: 0.0280, Val Loss: 0.0279
# EarlyStopping counter: 7 out of 20
# Epoch [70/10000], Train Loss: 0.0280, Val Loss: 0.0279
# EarlyStopping counter: 8 out of 20
# Epoch [71/10000], Train Loss: 0.0279, Val Loss: 0.0280
# EarlyStopping counter: 9 out of 20
# Epoch [72/10000], Train Loss: 0.0280, Val Loss: 0.0278
# Validation loss decreased (0.027836 --> 0.027833).  Saving model ...
# Epoch [73/10000], Train Loss: 0.0280, Val Loss: 0.0278
# Validation loss decreased (0.027833 --> 0.027807).  Saving model ...
# Epoch [74/10000], Train Loss: 0.0279, Val Loss: 0.0278
# Validation loss decreased (0.027807 --> 0.027805).  Saving model ...
# Epoch [75/10000], Train Loss: 0.0279, Val Loss: 0.0281
# EarlyStopping counter: 1 out of 20
# Epoch [76/10000], Train Loss: 0.0279, Val Loss: 0.0279
# EarlyStopping counter: 2 out of 20
# Epoch [77/10000], Train Loss: 0.0280, Val Loss: 0.0278
# Validation loss decreased (0.027805 --> 0.027797).  Saving model ...
# Epoch [78/10000], Train Loss: 0.0280, Val Loss: 0.0278
# EarlyStopping counter: 1 out of 20
# Epoch [79/10000], Train Loss: 0.0279, Val Loss: 0.0279
# EarlyStopping counter: 2 out of 20
# Epoch [80/10000], Train Loss: 0.0279, Val Loss: 0.0279
# EarlyStopping counter: 3 out of 20
# Epoch [81/10000], Train Loss: 0.0279, Val Loss: 0.0280
# EarlyStopping counter: 4 out of 20
# Epoch [82/10000], Train Loss: 0.0279, Val Loss: 0.0279
# EarlyStopping counter: 5 out of 20
# Epoch [83/10000], Train Loss: 0.0279, Val Loss: 0.0278
# EarlyStopping counter: 6 out of 20
# Epoch [84/10000], Train Loss: 0.0278, Val Loss: 0.0278
# EarlyStopping counter: 7 out of 20
# Epoch [85/10000], Train Loss: 0.0278, Val Loss: 0.0277
# Validation loss decreased (0.027797 --> 0.027731).  Saving model ...
# Epoch [86/10000], Train Loss: 0.0278, Val Loss: 0.0278
# EarlyStopping counter: 1 out of 20
# Epoch [87/10000], Train Loss: 0.0278, Val Loss: 0.0277
# Validation loss decreased (0.027731 --> 0.027660).  Saving model ...
# Epoch [88/10000], Train Loss: 0.0279, Val Loss: 0.0277
# EarlyStopping counter: 1 out of 20
# Epoch [89/10000], Train Loss: 0.0279, Val Loss: 0.0277
# EarlyStopping counter: 2 out of 20
# Epoch [90/10000], Train Loss: 0.0278, Val Loss: 0.0280
# EarlyStopping counter: 3 out of 20
# Epoch [91/10000], Train Loss: 0.0279, Val Loss: 0.0278
# EarlyStopping counter: 4 out of 20
# Epoch [92/10000], Train Loss: 0.0279, Val Loss: 0.0281
# EarlyStopping counter: 5 out of 20
# Epoch [93/10000], Train Loss: 0.0278, Val Loss: 0.0279
# EarlyStopping counter: 6 out of 20
# Epoch [94/10000], Train Loss: 0.0277, Val Loss: 0.0279
# EarlyStopping counter: 7 out of 20
# Epoch [95/10000], Train Loss: 0.0277, Val Loss: 0.0280
# EarlyStopping counter: 8 out of 20
# Epoch [96/10000], Train Loss: 0.0277, Val Loss: 0.0279
# EarlyStopping counter: 9 out of 20
# Epoch [97/10000], Train Loss: 0.0276, Val Loss: 0.0278
# EarlyStopping counter: 10 out of 20
# Epoch [98/10000], Train Loss: 0.0277, Val Loss: 0.0278
# EarlyStopping counter: 11 out of 20
# Epoch [99/10000], Train Loss: 0.0272, Val Loss: 0.0276
# Validation loss decreased (0.027660 --> 0.027556).  Saving model ...
# Epoch [100/10000], Train Loss: 0.0271, Val Loss: 0.0275
# Validation loss decreased (0.027556 --> 0.027516).  Saving model ...
# Epoch [101/10000], Train Loss: 0.0271, Val Loss: 0.0275
# Validation loss decreased (0.027516 --> 0.027474).  Saving model ...
# Epoch [102/10000], Train Loss: 0.0270, Val Loss: 0.0275
# Validation loss decreased (0.027474 --> 0.027452).  Saving model ...
# Epoch [103/10000], Train Loss: 0.0269, Val Loss: 0.0274
# Validation loss decreased (0.027452 --> 0.027417).  Saving model ...
# Epoch [104/10000], Train Loss: 0.0269, Val Loss: 0.0274
# Validation loss decreased (0.027417 --> 0.027379).  Saving model ...
# Epoch [105/10000], Train Loss: 0.0269, Val Loss: 0.0274
# EarlyStopping counter: 1 out of 20
# Epoch [106/10000], Train Loss: 0.0269, Val Loss: 0.0274
# EarlyStopping counter: 2 out of 20
# Epoch [107/10000], Train Loss: 0.0269, Val Loss: 0.0274
# EarlyStopping counter: 3 out of 20
# Epoch [108/10000], Train Loss: 0.0268, Val Loss: 0.0274
# EarlyStopping counter: 4 out of 20
# Epoch [109/10000], Train Loss: 0.0268, Val Loss: 0.0274
# EarlyStopping counter: 5 out of 20
# Epoch [110/10000], Train Loss: 0.0268, Val Loss: 0.0274
# EarlyStopping counter: 6 out of 20
# Epoch [111/10000], Train Loss: 0.0268, Val Loss: 0.0274
# EarlyStopping counter: 7 out of 20
# Epoch [112/10000], Train Loss: 0.0267, Val Loss: 0.0274
# Validation loss decreased (0.027379 --> 0.027354).  Saving model ...
# Epoch [113/10000], Train Loss: 0.0267, Val Loss: 0.0274
# EarlyStopping counter: 1 out of 20
# Epoch [114/10000], Train Loss: 0.0267, Val Loss: 0.0274
# EarlyStopping counter: 2 out of 20
# Epoch [115/10000], Train Loss: 0.0267, Val Loss: 0.0273
# Validation loss decreased (0.027354 --> 0.027335).  Saving model ...
# Epoch [116/10000], Train Loss: 0.0266, Val Loss: 0.0274
# EarlyStopping counter: 1 out of 20
# Epoch [117/10000], Train Loss: 0.0266, Val Loss: 0.0273
# Validation loss decreased (0.027335 --> 0.027318).  Saving model ...
# Epoch [118/10000], Train Loss: 0.0266, Val Loss: 0.0274
# EarlyStopping counter: 1 out of 20
# Epoch [119/10000], Train Loss: 0.0265, Val Loss: 0.0274
# EarlyStopping counter: 2 out of 20
# Epoch [120/10000], Train Loss: 0.0265, Val Loss: 0.0274
# EarlyStopping counter: 3 out of 20
# Epoch [121/10000], Train Loss: 0.0265, Val Loss: 0.0274
# EarlyStopping counter: 4 out of 20
# Epoch [122/10000], Train Loss: 0.0265, Val Loss: 0.0274
# EarlyStopping counter: 5 out of 20
# Epoch [123/10000], Train Loss: 0.0265, Val Loss: 0.0274
# EarlyStopping counter: 6 out of 20
# Epoch [124/10000], Train Loss: 0.0265, Val Loss: 0.0274
# EarlyStopping counter: 7 out of 20
# Epoch [125/10000], Train Loss: 0.0265, Val Loss: 0.0273
# EarlyStopping counter: 8 out of 20
# Epoch [126/10000], Train Loss: 0.0264, Val Loss: 0.0273
# Validation loss decreased (0.027318 --> 0.027309).  Saving model ...
# Epoch [127/10000], Train Loss: 0.0264, Val Loss: 0.0273
# EarlyStopping counter: 1 out of 20
# Epoch [128/10000], Train Loss: 0.0264, Val Loss: 0.0274
# EarlyStopping counter: 2 out of 20
# Epoch [129/10000], Train Loss: 0.0263, Val Loss: 0.0274
# EarlyStopping counter: 3 out of 20
# Epoch [130/10000], Train Loss: 0.0263, Val Loss: 0.0274
# EarlyStopping counter: 4 out of 20
# Epoch [131/10000], Train Loss: 0.0263, Val Loss: 0.0274
# EarlyStopping counter: 5 out of 20
# Epoch [132/10000], Train Loss: 0.0263, Val Loss: 0.0273
# EarlyStopping counter: 6 out of 20
# Epoch [133/10000], Train Loss: 0.0263, Val Loss: 0.0273
# EarlyStopping counter: 7 out of 20
# Epoch [134/10000], Train Loss: 0.0262, Val Loss: 0.0273
# Validation loss decreased (0.027309 --> 0.027307).  Saving model ...
# Epoch [135/10000], Train Loss: 0.0262, Val Loss: 0.0274
# EarlyStopping counter: 1 out of 20
# Epoch [136/10000], Train Loss: 0.0262, Val Loss: 0.0273
# EarlyStopping counter: 2 out of 20
# Epoch [137/10000], Train Loss: 0.0262, Val Loss: 0.0273
# EarlyStopping counter: 3 out of 20
# Epoch [138/10000], Train Loss: 0.0261, Val Loss: 0.0273
# EarlyStopping counter: 4 out of 20
# Epoch [139/10000], Train Loss: 0.0261, Val Loss: 0.0273
# EarlyStopping counter: 5 out of 20
# Epoch [140/10000], Train Loss: 0.0261, Val Loss: 0.0273
# EarlyStopping counter: 6 out of 20
# Epoch [141/10000], Train Loss: 0.0261, Val Loss: 0.0273
# EarlyStopping counter: 7 out of 20
# Epoch [142/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 8 out of 20
# Epoch [143/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 9 out of 20
# Epoch [144/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 10 out of 20
# Epoch [145/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 11 out of 20
# Epoch [146/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 12 out of 20
# Epoch [147/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 13 out of 20
# Epoch [148/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 14 out of 20
# Epoch [149/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 15 out of 20
# Epoch [150/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 16 out of 20
# Epoch [151/10000], Train Loss: 0.0259, Val Loss: 0.0273
# EarlyStopping counter: 17 out of 20
# Epoch [152/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 18 out of 20
# Epoch [153/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 19 out of 20
# Epoch [154/10000], Train Loss: 0.0260, Val Loss: 0.0273
# EarlyStopping counter: 20 out of 20
# Early stopping
# Best Validation Loss: 0.0273

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt


# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

# Initialize the autoencoder, loss function
autoencoder = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v).to(device)
criterion = nn.MSELoss()

# Function to load the model
def load_model(model, model_path):
    model.load_state_dict(torch.load(model_path))
    model.to(device)

# Function to visualize images
def visualize_images(model, data_loader):
    model.eval()
    inputs, targets = next(iter(data_loader))
    inputs, targets = inputs.to(device), targets.to(device)
    with torch.no_grad():
        outputs = model(inputs)
    
    inputs = inputs.cpu().numpy()
    targets = targets.cpu().numpy()
    outputs = outputs.cpu().numpy()
    
    fig, axes = plt.subplots(3, 5, figsize=(15, 9))
    for i in range(5):
        axes[0, i].imshow(inputs[i][0], cmap='gray')
        axes[0, i].set_title("Input")
        axes[1, i].imshow(targets[i][0], cmap='gray')
        axes[1, i].set_title("Target")
        axes[2, i].imshow(outputs[i][0], cmap='gray')
        axes[2, i].set_title("Output")
    
    plt.tight_layout()
    plt.show()

# Load the trained model
load_model(autoencoder, 'best_model_3_2_1.pth')

# Visualize the results on validation data
visualize_images(autoencoder, val_loader)
# Out:
# Using device: cuda

# %%
class CombinedNetwork(nn.Module):
    def __init__(self, seq_len, input_dim, num_heads, d_k, d_v):
        super(CombinedNetwork, self).__init__()
        
        self.encoder = nn.Sequential(
            SimpleLinearNetwork(),
            Time2Vec(seq_len),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim)
        )
        
        self.latent = nn.Sequential(
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
        )        
        
        
        self.decoder = nn.Sequential(
            nn.Linear(512, 64 * 8 * 8),  # (B, 512) -> (B, 64*8*8)
            nn.Unflatten(1, (64, 8, 8)),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 64, 8, 8) -> (B, 32, 16, 16)
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 32, 16, 16) -> (B, 16, 32, 32)
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 16, 32, 32) -> (B, 1, 64, 64)
            nn.Sigmoid()  # Ensure the output values are between 0 and 1
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.latent(x)
        x = self.decoder(x)
        return x

# 示例使用
seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

model = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v)
sample_input = torch.randn((32, 1, 64, 64))  # 假设输入是32个64x64的单通道图像
output = model(sample_input)
print(output.shape)  # 输出形状
# Out:
# torch.Size([32, 1, 64, 64])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

# Initialize the autoencoder, loss function and optimizer
autoencoder = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v).to(device)

# Load pretrained weights for encoder and decoder
autoencoder.encoder.load_state_dict(torch.load('best_encoder_2.pth'))
autoencoder.decoder.load_state_dict(torch.load('best_decoder_2.pth'))

# Freeze encoder and decoder
for param in autoencoder.encoder.parameters():
    param.requires_grad = False

for param in autoencoder.decoder.parameters():
    param.requires_grad = False

criterion = nn.MSELoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, autoencoder.parameters()), lr=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

# Early stopping class
class EarlyStopping:
    def __init__(self, patience=20, verbose=False, delta=0, path='checkpoint.pth'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# Function to save the model
def save_model(model, path):
    torch.save(model.state_dict(), path)

# Training function
def train_autoencoder(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience=20):
    early_stopping = EarlyStopping(patience=patience, verbose=True, path='best_model_3_2_3.pth')
    model.train()

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        avg_train_loss = running_loss / len(train_loader)

        # Validation step
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
        
        avg_val_loss = val_loss / len(val_loader)
        
        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
        
        # Adjust learning rate based on validation loss
        scheduler.step(avg_val_loss)

        # Check early stopping condition
        early_stopping(avg_val_loss, model)

        if early_stopping.early_stop:
            print("Early stopping")
            break

    # Load the best model
    model.load_state_dict(torch.load('best_model_3_2_3.pth'))
    
    # Print the best validation loss
    print(f'Best Validation Loss: {early_stopping.val_loss_min:.4f}')
    
    return model

# Evaluation function
def evaluate_autoencoder(model, dataloader):
    model.eval()
    original_images = []
    reconstructed_images = []
    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            original_images.extend(targets.cpu())
            reconstructed_images.extend(outputs.cpu())
            break  # Remove this line if you want to evaluate the whole dataset
    return original_images, reconstructed_images

# Assume train_loader, val_loader, and test_loader are defined and loaded elsewhere

# Train the autoencoder with early stopping
autoencoder = train_autoencoder(autoencoder, train_loader, val_loader, criterion, optimizer, scheduler, epochs=10000, patience=20)

# Evaluate the autoencoder
original_images, reconstructed_images = evaluate_autoencoder(autoencoder, test_loader)
# Out:
# Using device: cuda
# c:\Users\metho\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch [1/10000], Train Loss: 0.0685, Val Loss: 0.0607
# Validation loss decreased (inf --> 0.060679).  Saving model ...
# Epoch [2/10000], Train Loss: 0.0600, Val Loss: 0.0600
# Validation loss decreased (0.060679 --> 0.060039).  Saving model ...
# Epoch [3/10000], Train Loss: 0.0604, Val Loss: 0.0584
# Validation loss decreased (0.060039 --> 0.058424).  Saving model ...
# Epoch [4/10000], Train Loss: 0.0592, Val Loss: 0.0585
# EarlyStopping counter: 1 out of 20
# Epoch [5/10000], Train Loss: 0.0588, Val Loss: 0.0601
# EarlyStopping counter: 2 out of 20
# Epoch [6/10000], Train Loss: 0.0598, Val Loss: 0.0589
# EarlyStopping counter: 3 out of 20
# Epoch [7/10000], Train Loss: 0.0586, Val Loss: 0.0583
# Validation loss decreased (0.058424 --> 0.058323).  Saving model ...
# Epoch [8/10000], Train Loss: 0.0583, Val Loss: 0.0583
# Validation loss decreased (0.058323 --> 0.058269).  Saving model ...
# Epoch [9/10000], Train Loss: 0.0581, Val Loss: 0.0581
# Validation loss decreased (0.058269 --> 0.058126).  Saving model ...
# Epoch [10/10000], Train Loss: 0.0575, Val Loss: 0.0500
# Validation loss decreased (0.058126 --> 0.049972).  Saving model ...
# Epoch [11/10000], Train Loss: 0.0489, Val Loss: 0.0459
# Validation loss decreased (0.049972 --> 0.045867).  Saving model ...
# Epoch [12/10000], Train Loss: 0.0434, Val Loss: 0.0392
# Validation loss decreased (0.045867 --> 0.039207).  Saving model ...
# Epoch [13/10000], Train Loss: 0.0368, Val Loss: 0.0345
# Validation loss decreased (0.039207 --> 0.034457).  Saving model ...
# Epoch [14/10000], Train Loss: 0.0334, Val Loss: 0.0322
# Validation loss decreased (0.034457 --> 0.032156).  Saving model ...
# Epoch [15/10000], Train Loss: 0.0318, Val Loss: 0.0310
# Validation loss decreased (0.032156 --> 0.030978).  Saving model ...
# Epoch [16/10000], Train Loss: 0.0313, Val Loss: 0.0304
# Validation loss decreased (0.030978 --> 0.030361).  Saving model ...
# Epoch [17/10000], Train Loss: 0.0305, Val Loss: 0.0302
# Validation loss decreased (0.030361 --> 0.030182).  Saving model ...
# Epoch [18/10000], Train Loss: 0.0303, Val Loss: 0.0303
# EarlyStopping counter: 1 out of 20
# Epoch [19/10000], Train Loss: 0.0302, Val Loss: 0.0298
# Validation loss decreased (0.030182 --> 0.029762).  Saving model ...
# Epoch [20/10000], Train Loss: 0.0300, Val Loss: 0.0298
# EarlyStopping counter: 1 out of 20
# Epoch [21/10000], Train Loss: 0.0303, Val Loss: 0.0295
# Validation loss decreased (0.029762 --> 0.029479).  Saving model ...
# Epoch [22/10000], Train Loss: 0.0297, Val Loss: 0.0292
# Validation loss decreased (0.029479 --> 0.029210).  Saving model ...
# Epoch [23/10000], Train Loss: 0.0297, Val Loss: 0.0293
# EarlyStopping counter: 1 out of 20
# Epoch [24/10000], Train Loss: 0.0296, Val Loss: 0.0295
# EarlyStopping counter: 2 out of 20
# Epoch [25/10000], Train Loss: 0.0294, Val Loss: 0.0290
# Validation loss decreased (0.029210 --> 0.029014).  Saving model ...
# Epoch [26/10000], Train Loss: 0.0294, Val Loss: 0.0292
# EarlyStopping counter: 1 out of 20
# Epoch [27/10000], Train Loss: 0.0296, Val Loss: 0.0294
# EarlyStopping counter: 2 out of 20
# Epoch [28/10000], Train Loss: 0.0294, Val Loss: 0.0289
# Validation loss decreased (0.029014 --> 0.028906).  Saving model ...
# Epoch [29/10000], Train Loss: 0.0296, Val Loss: 0.0291
# EarlyStopping counter: 1 out of 20
# Epoch [30/10000], Train Loss: 0.0292, Val Loss: 0.0288
# Validation loss decreased (0.028906 --> 0.028773).  Saving model ...
# Epoch [31/10000], Train Loss: 0.0292, Val Loss: 0.0287
# Validation loss decreased (0.028773 --> 0.028662).  Saving model ...
# Epoch [32/10000], Train Loss: 0.0293, Val Loss: 0.0288
# EarlyStopping counter: 1 out of 20
# Epoch [33/10000], Train Loss: 0.0289, Val Loss: 0.0287
# EarlyStopping counter: 2 out of 20
# Epoch [34/10000], Train Loss: 0.0290, Val Loss: 0.0288
# EarlyStopping counter: 3 out of 20
# Epoch [35/10000], Train Loss: 0.0289, Val Loss: 0.0286
# Validation loss decreased (0.028662 --> 0.028609).  Saving model ...
# Epoch [36/10000], Train Loss: 0.0288, Val Loss: 0.0287
# EarlyStopping counter: 1 out of 20
# Epoch [37/10000], Train Loss: 0.0289, Val Loss: 0.0287
# EarlyStopping counter: 2 out of 20
# Epoch [38/10000], Train Loss: 0.0291, Val Loss: 0.0289
# EarlyStopping counter: 3 out of 20
# Epoch [39/10000], Train Loss: 0.0290, Val Loss: 0.0287
# EarlyStopping counter: 4 out of 20
# Epoch [40/10000], Train Loss: 0.0289, Val Loss: 0.0287
# EarlyStopping counter: 5 out of 20
# Epoch [41/10000], Train Loss: 0.0287, Val Loss: 0.0289
# EarlyStopping counter: 6 out of 20
# Epoch [42/10000], Train Loss: 0.0289, Val Loss: 0.0292
# EarlyStopping counter: 7 out of 20
# Epoch [43/10000], Train Loss: 0.0288, Val Loss: 0.0288
# EarlyStopping counter: 8 out of 20
# Epoch [44/10000], Train Loss: 0.0287, Val Loss: 0.0288
# EarlyStopping counter: 9 out of 20
# Epoch [45/10000], Train Loss: 0.0286, Val Loss: 0.0285
# Validation loss decreased (0.028609 --> 0.028495).  Saving model ...
# Epoch [46/10000], Train Loss: 0.0286, Val Loss: 0.0285
# EarlyStopping counter: 1 out of 20
# Epoch [47/10000], Train Loss: 0.0285, Val Loss: 0.0286
# EarlyStopping counter: 2 out of 20
# Epoch [48/10000], Train Loss: 0.0287, Val Loss: 0.0289
# EarlyStopping counter: 3 out of 20
# Epoch [49/10000], Train Loss: 0.0286, Val Loss: 0.0285
# EarlyStopping counter: 4 out of 20
# Epoch [50/10000], Train Loss: 0.0286, Val Loss: 0.0285
# Validation loss decreased (0.028495 --> 0.028487).  Saving model ...
# Epoch [51/10000], Train Loss: 0.0286, Val Loss: 0.0285
# EarlyStopping counter: 1 out of 20
# Epoch [52/10000], Train Loss: 0.0288, Val Loss: 0.0285
# EarlyStopping counter: 2 out of 20
# Epoch [53/10000], Train Loss: 0.0286, Val Loss: 0.0285
# Validation loss decreased (0.028487 --> 0.028477).  Saving model ...
# Epoch [54/10000], Train Loss: 0.0284, Val Loss: 0.0283
# Validation loss decreased (0.028477 --> 0.028307).  Saving model ...
# Epoch [55/10000], Train Loss: 0.0284, Val Loss: 0.0284
# EarlyStopping counter: 1 out of 20
# Epoch [56/10000], Train Loss: 0.0286, Val Loss: 0.0287
# EarlyStopping counter: 2 out of 20
# Epoch [57/10000], Train Loss: 0.0285, Val Loss: 0.0285
# EarlyStopping counter: 3 out of 20
# Epoch [58/10000], Train Loss: 0.0285, Val Loss: 0.0286
# EarlyStopping counter: 4 out of 20
# Epoch [59/10000], Train Loss: 0.0286, Val Loss: 0.0288
# EarlyStopping counter: 5 out of 20
# Epoch [60/10000], Train Loss: 0.0284, Val Loss: 0.0286
# EarlyStopping counter: 6 out of 20
# Epoch [61/10000], Train Loss: 0.0285, Val Loss: 0.0289
# EarlyStopping counter: 7 out of 20
# Epoch [62/10000], Train Loss: 0.0283, Val Loss: 0.0288
# EarlyStopping counter: 8 out of 20
# Epoch [63/10000], Train Loss: 0.0284, Val Loss: 0.0284
# EarlyStopping counter: 9 out of 20
# Epoch [64/10000], Train Loss: 0.0282, Val Loss: 0.0285
# EarlyStopping counter: 10 out of 20
# Epoch [65/10000], Train Loss: 0.0284, Val Loss: 0.0285
# EarlyStopping counter: 11 out of 20
# Epoch [66/10000], Train Loss: 0.0276, Val Loss: 0.0281
# Validation loss decreased (0.028307 --> 0.028112).  Saving model ...
# Epoch [67/10000], Train Loss: 0.0272, Val Loss: 0.0280
# Validation loss decreased (0.028112 --> 0.028013).  Saving model ...
# Epoch [68/10000], Train Loss: 0.0270, Val Loss: 0.0280
# Validation loss decreased (0.028013 --> 0.027952).  Saving model ...
# Epoch [69/10000], Train Loss: 0.0269, Val Loss: 0.0280
# EarlyStopping counter: 1 out of 20
# Epoch [70/10000], Train Loss: 0.0268, Val Loss: 0.0279
# Validation loss decreased (0.027952 --> 0.027897).  Saving model ...
# Epoch [71/10000], Train Loss: 0.0267, Val Loss: 0.0279
# Validation loss decreased (0.027897 --> 0.027861).  Saving model ...
# Epoch [72/10000], Train Loss: 0.0266, Val Loss: 0.0279
# Validation loss decreased (0.027861 --> 0.027850).  Saving model ...
# Epoch [73/10000], Train Loss: 0.0265, Val Loss: 0.0278
# Validation loss decreased (0.027850 --> 0.027834).  Saving model ...
# Epoch [74/10000], Train Loss: 0.0264, Val Loss: 0.0278
# Validation loss decreased (0.027834 --> 0.027827).  Saving model ...
# Epoch [75/10000], Train Loss: 0.0263, Val Loss: 0.0278
# Validation loss decreased (0.027827 --> 0.027799).  Saving model ...
# Epoch [76/10000], Train Loss: 0.0263, Val Loss: 0.0278
# Validation loss decreased (0.027799 --> 0.027784).  Saving model ...
# Epoch [77/10000], Train Loss: 0.0262, Val Loss: 0.0278
# EarlyStopping counter: 1 out of 20
# Epoch [78/10000], Train Loss: 0.0262, Val Loss: 0.0278
# Validation loss decreased (0.027784 --> 0.027769).  Saving model ...
# Epoch [79/10000], Train Loss: 0.0261, Val Loss: 0.0278
# EarlyStopping counter: 1 out of 20
# Epoch [80/10000], Train Loss: 0.0261, Val Loss: 0.0278
# Validation loss decreased (0.027769 --> 0.027768).  Saving model ...
# Epoch [81/10000], Train Loss: 0.0260, Val Loss: 0.0277
# Validation loss decreased (0.027768 --> 0.027747).  Saving model ...
# Epoch [82/10000], Train Loss: 0.0260, Val Loss: 0.0277
# EarlyStopping counter: 1 out of 20
# Epoch [83/10000], Train Loss: 0.0259, Val Loss: 0.0277
# Validation loss decreased (0.027747 --> 0.027745).  Saving model ...
# Epoch [84/10000], Train Loss: 0.0259, Val Loss: 0.0277
# Validation loss decreased (0.027745 --> 0.027725).  Saving model ...
# Epoch [85/10000], Train Loss: 0.0258, Val Loss: 0.0277
# Validation loss decreased (0.027725 --> 0.027722).  Saving model ...
# Epoch [86/10000], Train Loss: 0.0258, Val Loss: 0.0278
# EarlyStopping counter: 1 out of 20
# Epoch [87/10000], Train Loss: 0.0257, Val Loss: 0.0277
# EarlyStopping counter: 2 out of 20
# Epoch [88/10000], Train Loss: 0.0257, Val Loss: 0.0278
# EarlyStopping counter: 3 out of 20
# Epoch [89/10000], Train Loss: 0.0256, Val Loss: 0.0277
# EarlyStopping counter: 4 out of 20
# Epoch [90/10000], Train Loss: 0.0256, Val Loss: 0.0277
# EarlyStopping counter: 5 out of 20
# Epoch [91/10000], Train Loss: 0.0255, Val Loss: 0.0277
# EarlyStopping counter: 6 out of 20
# Epoch [92/10000], Train Loss: 0.0254, Val Loss: 0.0277
# EarlyStopping counter: 7 out of 20
# Epoch [93/10000], Train Loss: 0.0254, Val Loss: 0.0277
# EarlyStopping counter: 8 out of 20
# Epoch [94/10000], Train Loss: 0.0253, Val Loss: 0.0277
# Validation loss decreased (0.027722 --> 0.027720).  Saving model ...
# Epoch [95/10000], Train Loss: 0.0253, Val Loss: 0.0277
# EarlyStopping counter: 1 out of 20
# Epoch [96/10000], Train Loss: 0.0252, Val Loss: 0.0277
# EarlyStopping counter: 2 out of 20
# Epoch [97/10000], Train Loss: 0.0250, Val Loss: 0.0277
# EarlyStopping counter: 3 out of 20
# Epoch [98/10000], Train Loss: 0.0250, Val Loss: 0.0277
# Validation loss decreased (0.027720 --> 0.027718).  Saving model ...
# Epoch [99/10000], Train Loss: 0.0250, Val Loss: 0.0277
# Validation loss decreased (0.027718 --> 0.027706).  Saving model ...
# Epoch [100/10000], Train Loss: 0.0249, Val Loss: 0.0277
# Validation loss decreased (0.027706 --> 0.027700).  Saving model ...
# Epoch [101/10000], Train Loss: 0.0249, Val Loss: 0.0277
# Validation loss decreased (0.027700 --> 0.027698).  Saving model ...
# Epoch [102/10000], Train Loss: 0.0249, Val Loss: 0.0277
# EarlyStopping counter: 1 out of 20
# Epoch [103/10000], Train Loss: 0.0249, Val Loss: 0.0277
# EarlyStopping counter: 2 out of 20
# Epoch [104/10000], Train Loss: 0.0249, Val Loss: 0.0277
# EarlyStopping counter: 3 out of 20
# Epoch [105/10000], Train Loss: 0.0249, Val Loss: 0.0277
# EarlyStopping counter: 4 out of 20
# Epoch [106/10000], Train Loss: 0.0249, Val Loss: 0.0277
# EarlyStopping counter: 5 out of 20
# Epoch [107/10000], Train Loss: 0.0248, Val Loss: 0.0277
# Validation loss decreased (0.027698 --> 0.027697).  Saving model ...
# Epoch [108/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 1 out of 20
# Epoch [109/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 2 out of 20
# Epoch [110/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 3 out of 20
# Epoch [111/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 4 out of 20
# Epoch [112/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 5 out of 20
# Epoch [113/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 6 out of 20
# Epoch [114/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 7 out of 20
# Epoch [115/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 8 out of 20
# Epoch [116/10000], Train Loss: 0.0248, Val Loss: 0.0277
# EarlyStopping counter: 9 out of 20
# Epoch [117/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 10 out of 20
# Epoch [118/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 11 out of 20
# Epoch [119/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 12 out of 20
# Epoch [120/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 13 out of 20
# Epoch [121/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 14 out of 20
# Epoch [122/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 15 out of 20
# Epoch [123/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 16 out of 20
# Epoch [124/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 17 out of 20
# Epoch [125/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 18 out of 20
# Epoch [126/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 19 out of 20
# Epoch [127/10000], Train Loss: 0.0247, Val Loss: 0.0277
# EarlyStopping counter: 20 out of 20
# Early stopping
# Best Validation Loss: 0.0277

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt


# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

# Initialize the autoencoder, loss function
autoencoder = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v).to(device)
criterion = nn.MSELoss()

# Function to load the model
def load_model(model, model_path):
    model.load_state_dict(torch.load(model_path))
    model.to(device)

# Function to visualize images
def visualize_images(model, data_loader):
    model.eval()
    inputs, targets = next(iter(data_loader))
    inputs, targets = inputs.to(device), targets.to(device)
    with torch.no_grad():
        outputs = model(inputs)
    
    inputs = inputs.cpu().numpy()
    targets = targets.cpu().numpy()
    outputs = outputs.cpu().numpy()
    
    fig, axes = plt.subplots(3, 5, figsize=(15, 9))
    for i in range(5):
        axes[0, i].imshow(inputs[i][0], cmap='gray')
        axes[0, i].set_title("Input")
        axes[1, i].imshow(targets[i][0], cmap='gray')
        axes[1, i].set_title("Target")
        axes[2, i].imshow(outputs[i][0], cmap='gray')
        axes[2, i].set_title("Output")
    
    plt.tight_layout()
    plt.show()

# Load the trained model
load_model(autoencoder, 'best_model_3_2_3.pth')

# Visualize the results on validation data
visualize_images(autoencoder, val_loader)
# Out:
# Using device: cuda

# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
import matplotlib.pyplot as plt

class CustomDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')], key=lambda x: int(x.split('_')[1].split('.')[0]))
        self.transform = transform

    def __len__(self):
        return len(self.image_files) - 1  # Subtract 1 because the last image has no next image

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir, self.image_files[idx])
        next_img_name = os.path.join(self.image_dir, self.image_files[idx + 1])
        
        image = Image.open(img_name).convert('L')  # Convert image to grayscale
        next_image = Image.open(next_img_name).convert('L')  # Convert next image to grayscale
        
        if self.transform:
            image = self.transform(image)
            next_image = self.transform(next_image)
        
        return image, next_image

# Define the directory where images are stored
image_dir = 'images_10000'

# Define transformations (if any)
transform = transforms.Compose([
    transforms.ToTensor()
])

# Create the dataset
dataset = CustomDataset(image_dir=image_dir, transform=transform)

# Print the length of the dataset
print(f"Total dataset length: {len(dataset)}")

# Calculate lengths for train, val, test datasets
total_len = len(dataset)
train_len = int(0.6 * total_len)
val_len = int(0.2 * total_len)
test_len = total_len - train_len - val_len

# Print the lengths of the train, val, and test datasets
print(f"Train dataset length: {train_len}")
print(f"Validation dataset length: {val_len}")
print(f"Test dataset length: {test_len}")

# Create subsets manually by indices
train_indices = list(range(0, train_len))
val_indices = list(range(train_len, train_len + val_len))
test_indices = list(range(train_len + val_len, total_len))

train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Function to display images
def show_images(images, nrow=1, ncol=5):
    fig, axes = plt.subplots(nrow, ncol, figsize=(15, 3))
    for i in range(ncol):
        ax = axes[i]
        ax.imshow(images[i].squeeze(), cmap='gray')
        ax.axis('off')
    plt.show()

# Display the first five pairs of images in the dataset
if __name__ == '__main__':
    # Display the first five pairs of images
    first_five_pairs = [dataset[i] for i in range(5)]
    first_images = [pair[0] for pair in first_five_pairs]
    next_images = [pair[1] for pair in first_five_pairs]
    
    print("First images:")
    show_images(first_images)
    
    print("Next images:")
    show_images(next_images)
    
    # Example usage of data loaders
    for images, targets in train_loader:
        print(images.size(), targets.size())  # Example output: torch.Size([64, 1, H, W]) torch.Size([64, 1, H, W])
        break
# Out:
# Total dataset length: 9999
# Train dataset length: 5999
# Validation dataset length: 1999
# Test dataset length: 2001
# First images:
# Next images:
# torch.Size([16, 1, 64, 64]) torch.Size([16, 1, 64, 64])

# %%
class CombinedNetwork(nn.Module):
    def __init__(self, seq_len, input_dim, num_heads, d_k, d_v):
        super(CombinedNetwork, self).__init__()
        
        self.encoder = nn.Sequential(
            SimpleLinearNetwork(),
            Time2Vec(seq_len),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim)
        )
        
        self.latent = nn.Sequential(
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim)
        )        
        
        
        self.decoder = nn.Sequential(
            nn.Linear(512, 64 * 8 * 8),  # (B, 512) -> (B, 64*8*8)
            nn.Unflatten(1, (64, 8, 8)),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 64, 8, 8) -> (B, 32, 16, 16)
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 32, 16, 16) -> (B, 16, 32, 32)
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 16, 32, 32) -> (B, 1, 64, 64)
            nn.Sigmoid()  # Ensure the output values are between 0 and 1
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.latent(x)
        x = self.decoder(x)
        return x

# 示例使用
seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

model = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v)
sample_input = torch.randn((32, 1, 64, 64))  # 假设输入是32个64x64的单通道图像
output = model(sample_input)
print(output.shape)  # 输出形状
# Out:
# torch.Size([32, 1, 64, 64])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

# Initialize the autoencoder, loss function and optimizer
autoencoder = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v).to(device)

# Load pretrained weights for encoder and decoder
autoencoder.encoder.load_state_dict(torch.load('best_encoder_2.pth'))
autoencoder.decoder.load_state_dict(torch.load('best_decoder_2.pth'))

# Freeze encoder and decoder
for param in autoencoder.encoder.parameters():
    param.requires_grad = False

for param in autoencoder.decoder.parameters():
    param.requires_grad = False

criterion = nn.MSELoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, autoencoder.parameters()), lr=0.00001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

# Early stopping class
class EarlyStopping:
    def __init__(self, patience=20, verbose=False, delta=0, path='checkpoint.pth'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# Function to save the model
def save_model(model, path):
    torch.save(model.state_dict(), path)

# Training function
def train_autoencoder(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience=20):
    early_stopping = EarlyStopping(patience=patience, verbose=True, path='best_model_3_2_6.pth')
    model.train()

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        avg_train_loss = running_loss / len(train_loader)

        # Validation step
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
        
        avg_val_loss = val_loss / len(val_loader)
        
        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
        
        # Adjust learning rate based on validation loss
        scheduler.step(avg_val_loss)

        # Check early stopping condition
        early_stopping(avg_val_loss, model)

        if early_stopping.early_stop:
            print("Early stopping")
            break

    # Load the best model
    model.load_state_dict(torch.load('best_model_3_2_6.pth'))
    
    # Print the best validation loss
    print(f'Best Validation Loss: {early_stopping.val_loss_min:.4f}')
    
    return model

# Evaluation function
def evaluate_autoencoder(model, dataloader):
    model.eval()
    original_images = []
    reconstructed_images = []
    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            original_images.extend(targets.cpu())
            reconstructed_images.extend(outputs.cpu())
            break  # Remove this line if you want to evaluate the whole dataset
    return original_images, reconstructed_images

# Assume train_loader, val_loader, and test_loader are defined and loaded elsewhere

# Train the autoencoder with early stopping
autoencoder = train_autoencoder(autoencoder, train_loader, val_loader, criterion, optimizer, scheduler, epochs=10000, patience=20)

# Evaluate the autoencoder
original_images, reconstructed_images = evaluate_autoencoder(autoencoder, test_loader)
# Out:
# Using device: cuda
# Epoch [1/10000], Train Loss: 0.0609, Val Loss: 0.0597
# Validation loss decreased (inf --> 0.059652).  Saving model ...
# Epoch [2/10000], Train Loss: 0.0598, Val Loss: 0.0583
# Validation loss decreased (0.059652 --> 0.058258).  Saving model ...
# Epoch [3/10000], Train Loss: 0.0589, Val Loss: 0.0584
# EarlyStopping counter: 1 out of 20
# Epoch [4/10000], Train Loss: 0.0590, Val Loss: 0.0602
# EarlyStopping counter: 2 out of 20
# Epoch [5/10000], Train Loss: 0.0584, Val Loss: 0.0585
# EarlyStopping counter: 3 out of 20
# Epoch [6/10000], Train Loss: 0.0581, Val Loss: 0.0580
# Validation loss decreased (0.058258 --> 0.058047).  Saving model ...
# Epoch [7/10000], Train Loss: 0.0581, Val Loss: 0.0580
# Validation loss decreased (0.058047 --> 0.058037).  Saving model ...
# Epoch [8/10000], Train Loss: 0.0579, Val Loss: 0.0577
# Validation loss decreased (0.058037 --> 0.057737).  Saving model ...
# Epoch [9/10000], Train Loss: 0.0579, Val Loss: 0.0578
# EarlyStopping counter: 1 out of 20
# Epoch [10/10000], Train Loss: 0.0578, Val Loss: 0.0573
# Validation loss decreased (0.057737 --> 0.057348).  Saving model ...
# Epoch [11/10000], Train Loss: 0.0579, Val Loss: 0.0584
# EarlyStopping counter: 1 out of 20
# Epoch [12/10000], Train Loss: 0.0577, Val Loss: 0.0573
# Validation loss decreased (0.057348 --> 0.057332).  Saving model ...
# Epoch [13/10000], Train Loss: 0.0577, Val Loss: 0.0576
# EarlyStopping counter: 1 out of 20
# Epoch [14/10000], Train Loss: 0.0577, Val Loss: 0.0572
# Validation loss decreased (0.057332 --> 0.057236).  Saving model ...
# Epoch [15/10000], Train Loss: 0.0577, Val Loss: 0.0574
# EarlyStopping counter: 1 out of 20
# Epoch [16/10000], Train Loss: 0.0577, Val Loss: 0.0573
# EarlyStopping counter: 2 out of 20
# Epoch [17/10000], Train Loss: 0.0577, Val Loss: 0.0574
# EarlyStopping counter: 3 out of 20
# Epoch [18/10000], Train Loss: 0.0576, Val Loss: 0.0575
# EarlyStopping counter: 4 out of 20
# Epoch [19/10000], Train Loss: 0.0577, Val Loss: 0.0573
# EarlyStopping counter: 5 out of 20
# Epoch [20/10000], Train Loss: 0.0575, Val Loss: 0.0576
# EarlyStopping counter: 6 out of 20
# Epoch [21/10000], Train Loss: 0.0576, Val Loss: 0.0576
# EarlyStopping counter: 7 out of 20
# Epoch [22/10000], Train Loss: 0.0575, Val Loss: 0.0576
# EarlyStopping counter: 8 out of 20
# Epoch [23/10000], Train Loss: 0.0575, Val Loss: 0.0574
# EarlyStopping counter: 9 out of 20
# Epoch [24/10000], Train Loss: 0.0575, Val Loss: 0.0574
# EarlyStopping counter: 10 out of 20
# Epoch [25/10000], Train Loss: 0.0575, Val Loss: 0.0577
# EarlyStopping counter: 11 out of 20
# Epoch [26/10000], Train Loss: 0.0571, Val Loss: 0.0570
# Validation loss decreased (0.057236 --> 0.056976).  Saving model ...
# Epoch [27/10000], Train Loss: 0.0570, Val Loss: 0.0570
# Validation loss decreased (0.056976 --> 0.056964).  Saving model ...
# Epoch [28/10000], Train Loss: 0.0570, Val Loss: 0.0570
# Validation loss decreased (0.056964 --> 0.056955).  Saving model ...
# Epoch [29/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056955 --> 0.056950).  Saving model ...
# Epoch [30/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056950 --> 0.056944).  Saving model ...
# Epoch [31/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056944 --> 0.056939).  Saving model ...
# Epoch [32/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056939 --> 0.056936).  Saving model ...
# Epoch [33/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056936 --> 0.056933).  Saving model ...
# Epoch [34/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056933 --> 0.056927).  Saving model ...
# Epoch [35/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056927 --> 0.056926).  Saving model ...
# Epoch [36/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056926 --> 0.056923).  Saving model ...
# Epoch [37/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056923 --> 0.056919).  Saving model ...
# Epoch [38/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056919 --> 0.056916).  Saving model ...
# Epoch [39/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056916 --> 0.056914).  Saving model ...
# Epoch [40/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056914 --> 0.056912).  Saving model ...
# Epoch [41/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056912 --> 0.056909).  Saving model ...
# Epoch [42/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056909 --> 0.056907).  Saving model ...
# Epoch [43/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056907 --> 0.056904).  Saving model ...
# Epoch [44/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056904 --> 0.056901).  Saving model ...
# Epoch [45/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056901 --> 0.056900).  Saving model ...
# Epoch [46/10000], Train Loss: 0.0570, Val Loss: 0.0569
# Validation loss decreased (0.056900 --> 0.056899).  Saving model ...
# Epoch [47/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056899 --> 0.056897).  Saving model ...
# Epoch [48/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056897 --> 0.056895).  Saving model ...
# Epoch [49/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056895 --> 0.056893).  Saving model ...
# Epoch [50/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056893 --> 0.056892).  Saving model ...
# Epoch [51/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056892 --> 0.056890).  Saving model ...
# Epoch [52/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056890 --> 0.056888).  Saving model ...
# Epoch [53/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056888 --> 0.056888).  Saving model ...
# Epoch [54/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056888 --> 0.056887).  Saving model ...
# Epoch [55/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056887 --> 0.056884).  Saving model ...
# Epoch [56/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [57/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056884 --> 0.056883).  Saving model ...
# Epoch [58/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056883 --> 0.056881).  Saving model ...
# Epoch [59/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056881 --> 0.056880).  Saving model ...
# Epoch [60/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056880 --> 0.056878).  Saving model ...
# Epoch [61/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056878 --> 0.056877).  Saving model ...
# Epoch [62/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [63/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056877 --> 0.056874).  Saving model ...
# Epoch [64/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [65/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056874 --> 0.056873).  Saving model ...
# Epoch [66/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056873 --> 0.056871).  Saving model ...
# Epoch [67/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056871 --> 0.056871).  Saving model ...
# Epoch [68/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056871 --> 0.056869).  Saving model ...
# Epoch [69/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056869 --> 0.056868).  Saving model ...
# Epoch [70/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [71/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056868 --> 0.056866).  Saving model ...
# Epoch [72/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056866 --> 0.056866).  Saving model ...
# Epoch [73/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056866 --> 0.056865).  Saving model ...
# Epoch [74/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [75/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056865 --> 0.056862).  Saving model ...
# Epoch [76/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056862 --> 0.056862).  Saving model ...
# Epoch [77/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056862 --> 0.056860).  Saving model ...
# Epoch [78/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056860 --> 0.056859).  Saving model ...
# Epoch [79/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056859 --> 0.056858).  Saving model ...
# Epoch [80/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [81/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056858 --> 0.056856).  Saving model ...
# Epoch [82/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [83/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056856 --> 0.056855).  Saving model ...
# Epoch [84/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056855 --> 0.056854).  Saving model ...
# Epoch [85/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056854 --> 0.056853).  Saving model ...
# Epoch [86/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056853 --> 0.056853).  Saving model ...
# Epoch [87/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056853 --> 0.056851).  Saving model ...
# Epoch [88/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [89/10000], Train Loss: 0.0569, Val Loss: 0.0569
# Validation loss decreased (0.056851 --> 0.056851).  Saving model ...
# Epoch [90/10000], Train Loss: 0.0569, Val Loss: 0.0569
# EarlyStopping counter: 1 out of 20
# Epoch [91/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056851 --> 0.056849).  Saving model ...
# Epoch [92/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056849 --> 0.056849).  Saving model ...
# Epoch [93/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [94/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056849 --> 0.056848).  Saving model ...
# Epoch [95/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056848 --> 0.056847).  Saving model ...
# Epoch [96/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056847 --> 0.056845).  Saving model ...
# Epoch [97/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056845 --> 0.056845).  Saving model ...
# Epoch [98/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [99/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056845 --> 0.056844).  Saving model ...
# Epoch [100/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [101/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 2 out of 20
# Epoch [102/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056844 --> 0.056841).  Saving model ...
# Epoch [103/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056841 --> 0.056840).  Saving model ...
# Epoch [104/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [105/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 2 out of 20
# Epoch [106/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 3 out of 20
# Epoch [107/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056840 --> 0.056839).  Saving model ...
# Epoch [108/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056839 --> 0.056838).  Saving model ...
# Epoch [109/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056838 --> 0.056837).  Saving model ...
# Epoch [110/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056837 --> 0.056837).  Saving model ...
# Epoch [111/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [112/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056837 --> 0.056836).  Saving model ...
# Epoch [113/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056836 --> 0.056835).  Saving model ...
# Epoch [114/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [115/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056835 --> 0.056834).  Saving model ...
# Epoch [116/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056834 --> 0.056834).  Saving model ...
# Epoch [117/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056834 --> 0.056833).  Saving model ...
# Epoch [118/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [119/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 2 out of 20
# Epoch [120/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056833 --> 0.056832).  Saving model ...
# Epoch [121/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056832 --> 0.056831).  Saving model ...
# Epoch [122/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056831 --> 0.056831).  Saving model ...
# Epoch [123/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056831 --> 0.056830).  Saving model ...
# Epoch [124/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056830 --> 0.056829).  Saving model ...
# Epoch [125/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [126/10000], Train Loss: 0.0569, Val Loss: 0.0568
# Validation loss decreased (0.056829 --> 0.056829).  Saving model ...
# Epoch [127/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [128/10000], Train Loss: 0.0569, Val Loss: 0.0568
# EarlyStopping counter: 2 out of 20
# Epoch [129/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056829 --> 0.056824).  Saving model ...
# Epoch [130/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056824 --> 0.056823).  Saving model ...
# Epoch [131/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056823 --> 0.056823).  Saving model ...
# Epoch [132/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056823 --> 0.056823).  Saving model ...
# Epoch [133/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056823 --> 0.056822).  Saving model ...
# Epoch [134/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [135/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056822 --> 0.056822).  Saving model ...
# Epoch [136/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [137/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056822 --> 0.056822).  Saving model ...
# Epoch [138/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [139/10000], Train Loss: 0.0568, Val Loss: 0.0568
# Validation loss decreased (0.056822 --> 0.056822).  Saving model ...
# Epoch [140/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 1 out of 20
# Epoch [141/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 2 out of 20
# Epoch [142/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 3 out of 20
# Epoch [143/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 4 out of 20
# Epoch [144/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 5 out of 20
# Epoch [145/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 6 out of 20
# Epoch [146/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 7 out of 20
# Epoch [147/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 8 out of 20
# Epoch [148/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 9 out of 20
# Epoch [149/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 10 out of 20
# Epoch [150/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 11 out of 20
# Epoch [151/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 12 out of 20
# Epoch [152/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 13 out of 20
# Epoch [153/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 14 out of 20
# Epoch [154/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 15 out of 20
# Epoch [155/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 16 out of 20
# Epoch [156/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 17 out of 20
# Epoch [157/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 18 out of 20
# Epoch [158/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 19 out of 20
# Epoch [159/10000], Train Loss: 0.0568, Val Loss: 0.0568
# EarlyStopping counter: 20 out of 20
# Early stopping
# Best Validation Loss: 0.0568

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt


# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

# Initialize the autoencoder, loss function
autoencoder = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v).to(device)
criterion = nn.MSELoss()

# Function to load the model
def load_model(model, model_path):
    model.load_state_dict(torch.load(model_path))
    model.to(device)

# Function to visualize images
def visualize_images(model, data_loader):
    model.eval()
    inputs, targets = next(iter(data_loader))
    inputs, targets = inputs.to(device), targets.to(device)
    with torch.no_grad():
        outputs = model(inputs)
    
    inputs = inputs.cpu().numpy()
    targets = targets.cpu().numpy()
    outputs = outputs.cpu().numpy()
    
    fig, axes = plt.subplots(3, 5, figsize=(15, 9))
    for i in range(5):
        axes[0, i].imshow(inputs[i][0], cmap='gray')
        axes[0, i].set_title("Input")
        axes[1, i].imshow(targets[i][0], cmap='gray')
        axes[1, i].set_title("Target")
        axes[2, i].imshow(outputs[i][0], cmap='gray')
        axes[2, i].set_title("Output")
    
    plt.tight_layout()
    plt.show()

# Load the trained model
load_model(autoencoder, 'best_model_3_2_6.pth')

# Visualize the results on validation data
visualize_images(autoencoder, val_loader)
# Out:
# Using device: cuda
