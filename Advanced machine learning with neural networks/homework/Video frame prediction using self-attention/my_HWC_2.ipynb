# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
import matplotlib.pyplot as plt

class CustomDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')], key=lambda x: int(x.split('_')[1].split('.')[0]))
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir, self.image_files[idx])
        image = Image.open(img_name).convert('L')  # Convert image to grayscale
        if self.transform:
            image = self.transform(image)
        return image

# Define the directory where images are stored
image_dir = 'images_10000'

# Define transformations (if any)
transform = transforms.Compose([
    transforms.ToTensor()
])

# Create the dataset
dataset = CustomDataset(image_dir=image_dir, transform=transform)

# Calculate lengths for train, val, test datasets
total_len = len(dataset)
train_len = int(0.8 * total_len)
val_len = int(0.1 * total_len)
test_len = total_len - train_len - val_len

# Create subsets manually by indices
train_indices = list(range(0, train_len))
val_indices = list(range(train_len, train_len + val_len))
test_indices = list(range(train_len + val_len, total_len))

train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)

# Print the lengths of each dataset
print(f'Train dataset length: {len(train_dataset)}')
print(f'Validation dataset length: {len(val_dataset)}')
print(f'Test dataset length: {len(test_dataset)}')

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

# Function to display images
def show_images(images, nrow=1, ncol=5):
    fig, axes = plt.subplots(nrow, ncol, figsize=(15, 3))
    for i in range(ncol):
        ax = axes[i]
        ax.imshow(images[i].squeeze(), cmap='gray')
        ax.axis('off')
    plt.show()

# Display the first five images in the dataset
if __name__ == '__main__':
    # Display the first five images
    first_five_images = [dataset[i] for i in range(5)]
    show_images(first_five_images)
    
    # Example usage of data loaders
    for images in train_loader:
        print(images.size())  # Example output: torch.Size([64, 1, H, W])
        break
# Out:
# Train dataset length: 8000
# Validation dataset length: 1000
# Test dataset length: 1000
# torch.Size([256, 1, 64, 64])

# %%
import torch
import torch.nn as nn

class SimpleLinearNetwork(nn.Module):
    def __init__(self):
        super(SimpleLinearNetwork, self).__init__()
        self.flatten = nn.Flatten()  # 将输入展平
        self.linear = nn.Linear(64 * 64, 256)  # 一个线性层

    def forward(self, x):
        x = self.flatten(x)  # 展平输入
        x = self.linear(x)  # 线性层变换
        return x

# 示例张量 (B, 1, 64, 64)
input_tensor = torch.randn(8, 1, 64, 64)  # 这里 B = 8 作为示例

# 创建网络实例
model = SimpleLinearNetwork()

# 前向传播
output_tensor = model(input_tensor)
print(output_tensor.shape)  # 期望输出 (B, 256)，这里 B = 8
# Out:
# torch.Size([8, 256])

# %%
import torch
import torch.nn as nn

class Time2Vec(nn.Module):
    def __init__(self, seq_len):
        super(Time2Vec, self).__init__()
        self.seq_len = seq_len
        self.weights_linear = nn.Parameter(torch.Tensor(seq_len // 2))
        self.bias_linear = nn.Parameter(torch.Tensor(seq_len // 2))
        self.weights_periodic = nn.Parameter(torch.Tensor(seq_len // 2))
        self.bias_periodic = nn.Parameter(torch.Tensor(seq_len // 2))
        self.reset_parameters()

    def reset_parameters(self):
        nn.init.uniform_(self.weights_linear)
        nn.init.uniform_(self.bias_linear)
        nn.init.uniform_(self.weights_periodic)
        nn.init.uniform_(self.bias_periodic)

    def forward(self, x):
        x_mean = torch.mean(x, dim=-1, keepdim=True)  # (B, 256) -> (B, 1)
        
        # 线性时间嵌入
        time_linear = self.weights_linear * x_mean + self.bias_linear  # (B, 1) -> (B, 128)
        
        # 周期性时间嵌入
        time_periodic = torch.sin(self.weights_periodic * x_mean + self.bias_periodic)  # (B, 1) -> (B, 128)
        
        # 拼接线性和周期性时间嵌入
        time_embedding = torch.cat([time_linear, time_periodic], dim=-1)  # (B, 128) and (B, 128) -> (B, 256)
        
        # 残差连接，将输入x与时间嵌入拼接
        residual_connection = torch.cat([x, time_embedding], dim=-1)  # (B, 256) and (B, 256) -> (B, 512)
        
        return residual_connection

# 示例用法
input_tensor = torch.randn(32, 256)  # (B, 256)
model = Time2Vec(seq_len=256)
output_tensor = model(input_tensor)  # (B, 512)

print(output_tensor.shape)  # 应输出: torch.Size([32, 512])
# Out:
# torch.Size([32, 512])

# %%
import torch
import torch.nn as nn

class SingleAttentionHead(nn.Module):
    def __init__(self, input_dim, d_k, d_v):
        super(SingleAttentionHead, self).__init__()
        self.d_k = d_k
        self.d_v = d_v

        self.W_Q = nn.Linear(input_dim, d_k)  # (input_dim, d_k)
        self.W_K = nn.Linear(input_dim, d_k)  # (input_dim, d_k)
        self.W_V = nn.Linear(input_dim, d_v)  # (input_dim, d_v)
        self.softmax = nn.Softmax(dim=-1)  # 使用 nn.Softmax

    def forward(self, X):
        # X: (B, input_dim)
        Q = self.W_Q(X)  # (B, d_k)
        K = self.W_K(X)  # (B, d_k)
        V = self.W_V(X)  # (B, d_v)

        # scores: (B, B)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / torch.sqrt(torch.tensor(self.d_k, dtype=torch.float32))  
        
        # attention_weights: (B, B)
        attention_weights = self.softmax(scores)
        
        # attention_output: (B, d_v)
        attention_output = torch.matmul(attention_weights, V)  

        return attention_output

# 示例使用
B = 32  # 批次大小
input_dim = 512  # 输入维度
d_k = 64
d_v = 128

# 随机生成输入张量
X = torch.randn(B, input_dim)

# 创建注意力头实例
attention_head = SingleAttentionHead(input_dim, d_k, d_v)

# 前向传播
output = attention_head(X)

print("Attention Output Shape:", output.shape)  # 输出应为 (B, d_v)
# Out:
# Attention Output Shape: torch.Size([32, 128])

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, input_dim, num_heads, d_k, d_v):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_k = d_k
        self.d_v = d_v

        # 创建多个注意力头，每个注意力头都是一个SingleAttentionHead实例
        self.attention_heads = nn.ModuleList([SingleAttentionHead(input_dim, d_k, d_v) for _ in range(num_heads)])
        self.W_O = nn.Linear(num_heads * d_v, input_dim)  # (num_heads * d_v, input_dim)


    def forward(self, X):
        # X: (B, input_dim)
        
        # 获取所有头的注意力输出，列表中的每个元素形状为 (B, d_v)
        attention_outputs = [head(X) for head in self.attention_heads]
        
        # 拼接所有头的输出，结果形状为 (B, num_heads * d_v)
        concat_output = torch.cat(attention_outputs, dim=-1)
        
        # 通过线性变换，最终输出形状为 (B, input_dim)
        output = self.W_O(concat_output)
        
        return output

# 示例使用
B = 32  # 批次大小
input_dim = 512  # 输入维度
num_heads = 32  # 头的数量
d_k = 64
d_v = 128

# 随机生成输入张量
X = torch.randn(B, input_dim)

# 创建多头注意力实例
multi_head_attention = MultiHeadAttention(input_dim, num_heads, d_k, d_v)

# 前向传播
output = multi_head_attention(X)

print("Multi-Head Attention Output Shape:", output.shape)  # 输出应为 (B, input_dim)
# Out:
# Multi-Head Attention Output Shape: torch.Size([32, 512])

# %%
import torch
import torch.nn as nn

class ProcessingModule(nn.Module):
    def __init__(self, input_dim=512, hidden_dim=2048, dropout_rate=0.1):
        super(ProcessingModule, self).__init__()
        self.dropout = nn.Dropout(dropout_rate)
        self.norm1 = nn.LayerNorm(input_dim)
        self.feed_forward = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )
        self.norm2 = nn.LayerNorm(input_dim)

    def forward(self, x):
        # Residual connection around dropout and normalization
        residual = x
        x = self.dropout(x)
        x = self.norm1(x + residual)
        
        # Feed-forward network
        x = self.feed_forward(x)
        
        # Add residual connection and apply final normalization
        x = self.norm2(x + residual)
        
        return x

# Example usage
batch_size = 32  # Example batch size
input_tensor = torch.randn((batch_size, 512))  # replace batch_size with your batch size
model = ProcessingModule()
output = model(input_tensor)

print("Output shape:", output.shape)  # Print output shape
# Out:
# Output shape: torch.Size([32, 512])

# %%
class CombinedNetwork(nn.Module):
    def __init__(self, seq_len, input_dim, num_heads, d_k, d_v):
        super(CombinedNetwork, self).__init__()
        
        self.encoder = nn.Sequential(
            SimpleLinearNetwork(),
            Time2Vec(seq_len),
            MultiHeadAttention(input_dim, num_heads, d_k, d_v),
            ProcessingModule(input_dim=input_dim)
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(512, 64 * 8 * 8),  # (B, 512) -> (B, 64*8*8)
            nn.Unflatten(1, (64, 8, 8)),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 64, 8, 8) -> (B, 32, 16, 16)
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 32, 16, 16) -> (B, 16, 32, 32)
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),  # (B, 16, 32, 32) -> (B, 1, 64, 64)
            nn.Sigmoid()  # Ensure the output values are between 0 and 1
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# 示例使用
seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

model = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v)
sample_input = torch.randn((32, 1, 64, 64))  # 假设输入是32个64x64的单通道图像
output = model(sample_input)
print(output.shape)  # 输出形状
# Out:
# torch.Size([32, 1, 64, 64])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

seq_len = 256
input_dim = 512
num_heads = 32
d_k = 64
d_v = 128

print(f'Using device: {device}')

# Define the CombinedNetwork class here (assumed to be defined elsewhere in your code)
# class CombinedNetwork(nn.Module):
#     def __init__(self, seq_len, input_dim, num_heads, d_k, d_v):
#         # Initialization code here

# Initialize the autoencoder, loss function and optimizer
autoencoder = CombinedNetwork(seq_len, input_dim, num_heads, d_k, d_v).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(autoencoder.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

# Early stopping class
class EarlyStopping:
    def __init__(self, patience=20, verbose=False, delta=0, encoder_path='best_encoder_2.pth', decoder_path='best_decoder_2.pth'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.encoder_path = encoder_path
        self.decoder_path = decoder_path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decreases.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.encoder.state_dict(), self.encoder_path)
        torch.save(model.decoder.state_dict(), self.decoder_path)
        self.val_loss_min = val_loss

# Function to save the model
def save_model(model, encoder_path, decoder_path):
    torch.save(model.encoder.state_dict(), encoder_path)
    torch.save(model.decoder.state_dict(), decoder_path)

# Training function with early stopping
def train_autoencoder(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience=20):
    early_stopping = EarlyStopping(patience=patience, verbose=True, encoder_path='best_encoder_2.pth', decoder_path='best_decoder_2.pth')
    model.train()

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for images in train_loader:
            images = images.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, images)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        avg_train_loss = running_loss / len(train_loader)

        # Validation step
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for images in val_loader:
                images = images.to(device)
                outputs = model(images)
                loss = criterion(outputs, images)
                val_loss += loss.item()
        
        avg_val_loss = val_loss / len(val_loader)
        
        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
        
        # Adjust learning rate based on validation loss
        scheduler.step(avg_val_loss)

        # Check early stopping condition
        early_stopping(avg_val_loss, model)

        if early_stopping.early_stop:
            print("Early stopping")
            break

    # Load the best model
    model.encoder.load_state_dict(torch.load('best_encoder_2.pth'))
    model.decoder.load_state_dict(torch.load('best_decoder_2.pth'))
    
    # Print the best validation loss
    print(f'Best Validation Loss: {early_stopping.val_loss_min:.4f}')
    
    return model

# Evaluation function
def evaluate_autoencoder(model, dataloader):
    model.eval()
    original_images = []
    reconstructed_images = []
    with torch.no_grad():
        for images in dataloader:
            images = images.to(device)
            outputs = model(images)
            original_images.extend(images.cpu())
            reconstructed_images.extend(outputs.cpu())
            break  # Remove this line if you want to evaluate the whole dataset
    return original_images, reconstructed_images

# Assume train_loader, val_loader, and test_loader are defined and loaded elsewhere

# Train the autoencoder with early stopping
autoencoder = train_autoencoder(autoencoder, train_loader, val_loader, criterion, optimizer, scheduler, epochs=10000, patience=20)

# Evaluate the autoencoder
original_images, reconstructed_images = evaluate_autoencoder(autoencoder, test_loader)

# Function to display images (assumed to be defined elsewhere in your code)
# def show_images(images, nrow, ncol):
#     # Display code here

# Display original and reconstructed images
show_images([original_images[i] for i in range(5)], nrow=1, ncol=5)
show_images([reconstructed_images[i] for i in range(5)], nrow=1, ncol=5)
# Out:
# Using device: cuda
# Epoch [1/10000], Train Loss: 0.1254, Val Loss: 0.0769
# Validation loss decreased (inf --> 0.076930).  Saving model ...
# Epoch [2/10000], Train Loss: 0.0697, Val Loss: 0.0636
# Validation loss decreased (0.076930 --> 0.063569).  Saving model ...
# Epoch [3/10000], Train Loss: 0.0565, Val Loss: 0.0398
# Validation loss decreased (0.063569 --> 0.039832).  Saving model ...
# Epoch [4/10000], Train Loss: 0.0215, Val Loss: 0.0095
# Validation loss decreased (0.039832 --> 0.009516).  Saving model ...
# Epoch [5/10000], Train Loss: 0.0067, Val Loss: 0.0046
# Validation loss decreased (0.009516 --> 0.004550).  Saving model ...
# Epoch [6/10000], Train Loss: 0.0034, Val Loss: 0.0033
# Validation loss decreased (0.004550 --> 0.003292).  Saving model ...
# Epoch [7/10000], Train Loss: 0.0025, Val Loss: 0.0025
# Validation loss decreased (0.003292 --> 0.002543).  Saving model ...
# Epoch [8/10000], Train Loss: 0.0018, Val Loss: 0.0025
# Validation loss decreased (0.002543 --> 0.002489).  Saving model ...
# Epoch [9/10000], Train Loss: 0.0019, Val Loss: 0.0017
# Validation loss decreased (0.002489 --> 0.001659).  Saving model ...
# Epoch [10/10000], Train Loss: 0.0016, Val Loss: 0.0015
# Validation loss decreased (0.001659 --> 0.001495).  Saving model ...
# Epoch [11/10000], Train Loss: 0.0014, Val Loss: 0.0024
# EarlyStopping counter: 1 out of 20
# Epoch [12/10000], Train Loss: 0.0020, Val Loss: 0.0030
# EarlyStopping counter: 2 out of 20
# Epoch [13/10000], Train Loss: 0.0019, Val Loss: 0.0016
# EarlyStopping counter: 3 out of 20
# Epoch [14/10000], Train Loss: 0.0013, Val Loss: 0.0014
# Validation loss decreased (0.001495 --> 0.001406).  Saving model ...
# Epoch [15/10000], Train Loss: 0.0014, Val Loss: 0.0016
# EarlyStopping counter: 1 out of 20
# Epoch [16/10000], Train Loss: 0.0013, Val Loss: 0.0019
# EarlyStopping counter: 2 out of 20
# Epoch [17/10000], Train Loss: 0.0015, Val Loss: 0.0020
# EarlyStopping counter: 3 out of 20
# Epoch [18/10000], Train Loss: 0.0017, Val Loss: 0.0018
# EarlyStopping counter: 4 out of 20
# Epoch [19/10000], Train Loss: 0.0016, Val Loss: 0.0019
# EarlyStopping counter: 5 out of 20
# Epoch [20/10000], Train Loss: 0.0019, Val Loss: 0.0049
# EarlyStopping counter: 6 out of 20
# Epoch [21/10000], Train Loss: 0.0036, Val Loss: 0.0021
# EarlyStopping counter: 7 out of 20
# Epoch [22/10000], Train Loss: 0.0014, Val Loss: 0.0010
# Validation loss decreased (0.001406 --> 0.001014).  Saving model ...
# Epoch [23/10000], Train Loss: 0.0010, Val Loss: 0.0009
# Validation loss decreased (0.001014 --> 0.000909).  Saving model ...
# Epoch [24/10000], Train Loss: 0.0008, Val Loss: 0.0008
# Validation loss decreased (0.000909 --> 0.000785).  Saving model ...
# Epoch [25/10000], Train Loss: 0.0009, Val Loss: 0.0012
# EarlyStopping counter: 1 out of 20
# Epoch [26/10000], Train Loss: 0.0011, Val Loss: 0.0008
# EarlyStopping counter: 2 out of 20
# Epoch [27/10000], Train Loss: 0.0009, Val Loss: 0.0009
# EarlyStopping counter: 3 out of 20
# Epoch [28/10000], Train Loss: 0.0009, Val Loss: 0.0009
# EarlyStopping counter: 4 out of 20
# Epoch [29/10000], Train Loss: 0.0007, Val Loss: 0.0007
# Validation loss decreased (0.000785 --> 0.000712).  Saving model ...
# Epoch [30/10000], Train Loss: 0.0007, Val Loss: 0.0008
# EarlyStopping counter: 1 out of 20
# Epoch [31/10000], Train Loss: 0.0009, Val Loss: 0.0013
# EarlyStopping counter: 2 out of 20
# Epoch [32/10000], Train Loss: 0.0011, Val Loss: 0.0016
# EarlyStopping counter: 3 out of 20
# Epoch [33/10000], Train Loss: 0.0018, Val Loss: 0.0019
# EarlyStopping counter: 4 out of 20
# Epoch [34/10000], Train Loss: 0.0017, Val Loss: 0.0016
# EarlyStopping counter: 5 out of 20
# Epoch [35/10000], Train Loss: 0.0013, Val Loss: 0.0012
# EarlyStopping counter: 6 out of 20
# Epoch [36/10000], Train Loss: 0.0011, Val Loss: 0.0012
# EarlyStopping counter: 7 out of 20
# Epoch [37/10000], Train Loss: 0.0011, Val Loss: 0.0010
# EarlyStopping counter: 8 out of 20
# Epoch [38/10000], Train Loss: 0.0010, Val Loss: 0.0013
# EarlyStopping counter: 9 out of 20
# Epoch [39/10000], Train Loss: 0.0011, Val Loss: 0.0012
# EarlyStopping counter: 10 out of 20
# Epoch [40/10000], Train Loss: 0.0012, Val Loss: 0.0012
# EarlyStopping counter: 11 out of 20
# Epoch [41/10000], Train Loss: 0.0009, Val Loss: 0.0008
# EarlyStopping counter: 12 out of 20
# Epoch [42/10000], Train Loss: 0.0007, Val Loss: 0.0007
# Validation loss decreased (0.000712 --> 0.000712).  Saving model ...
# Epoch [43/10000], Train Loss: 0.0007, Val Loss: 0.0007
# Validation loss decreased (0.000712 --> 0.000655).  Saving model ...
# Epoch [44/10000], Train Loss: 0.0006, Val Loss: 0.0006
# Validation loss decreased (0.000655 --> 0.000613).  Saving model ...
# Epoch [45/10000], Train Loss: 0.0006, Val Loss: 0.0006
# Validation loss decreased (0.000613 --> 0.000589).  Saving model ...
# Epoch [46/10000], Train Loss: 0.0006, Val Loss: 0.0006
# Validation loss decreased (0.000589 --> 0.000573).  Saving model ...
# Epoch [47/10000], Train Loss: 0.0006, Val Loss: 0.0006
# Validation loss decreased (0.000573 --> 0.000562).  Saving model ...
# Epoch [48/10000], Train Loss: 0.0006, Val Loss: 0.0006
# Validation loss decreased (0.000562 --> 0.000555).  Saving model ...
# Epoch [49/10000], Train Loss: 0.0005, Val Loss: 0.0006
# EarlyStopping counter: 1 out of 20
# Epoch [50/10000], Train Loss: 0.0005, Val Loss: 0.0005
# Validation loss decreased (0.000555 --> 0.000521).  Saving model ...
# Epoch [51/10000], Train Loss: 0.0005, Val Loss: 0.0005
# Validation loss decreased (0.000521 --> 0.000514).  Saving model ...
# Epoch [52/10000], Train Loss: 0.0005, Val Loss: 0.0005
# Validation loss decreased (0.000514 --> 0.000502).  Saving model ...
# Epoch [53/10000], Train Loss: 0.0005, Val Loss: 0.0005
# Validation loss decreased (0.000502 --> 0.000474).  Saving model ...
# Epoch [54/10000], Train Loss: 0.0005, Val Loss: 0.0005
# EarlyStopping counter: 1 out of 20
# Epoch [55/10000], Train Loss: 0.0004, Val Loss: 0.0005
# Validation loss decreased (0.000474 --> 0.000468).  Saving model ...
# Epoch [56/10000], Train Loss: 0.0004, Val Loss: 0.0005
# Validation loss decreased (0.000468 --> 0.000466).  Saving model ...
# Epoch [57/10000], Train Loss: 0.0004, Val Loss: 0.0005
# Validation loss decreased (0.000466 --> 0.000452).  Saving model ...
# Epoch [58/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000452 --> 0.000447).  Saving model ...
# Epoch [59/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000447 --> 0.000426).  Saving model ...
# Epoch [60/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 1 out of 20
# Epoch [61/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 2 out of 20
# Epoch [62/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 3 out of 20
# Epoch [63/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000426 --> 0.000420).  Saving model ...
# Epoch [64/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000420 --> 0.000418).  Saving model ...
# Epoch [65/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000418 --> 0.000404).  Saving model ...
# Epoch [66/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 1 out of 20
# Epoch [67/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 2 out of 20
# Epoch [68/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000404 --> 0.000400).  Saving model ...
# Epoch [69/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000400 --> 0.000391).  Saving model ...
# Epoch [70/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000391 --> 0.000375).  Saving model ...
# Epoch [71/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 1 out of 20
# Epoch [72/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 2 out of 20
# Epoch [73/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 3 out of 20
# Epoch [74/10000], Train Loss: 0.0004, Val Loss: 0.0004
# EarlyStopping counter: 4 out of 20
# Epoch [75/10000], Train Loss: 0.0004, Val Loss: 0.0004
# Validation loss decreased (0.000375 --> 0.000373).  Saving model ...
# Epoch [76/10000], Train Loss: 0.0003, Val Loss: 0.0004
# Validation loss decreased (0.000373 --> 0.000365).  Saving model ...
# Epoch [77/10000], Train Loss: 0.0003, Val Loss: 0.0004
# Validation loss decreased (0.000365 --> 0.000359).  Saving model ...
# Epoch [78/10000], Train Loss: 0.0003, Val Loss: 0.0004
# Validation loss decreased (0.000359 --> 0.000358).  Saving model ...
# Epoch [79/10000], Train Loss: 0.0003, Val Loss: 0.0004
# Validation loss decreased (0.000358 --> 0.000351).  Saving model ...
# Epoch [80/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000351 --> 0.000341).  Saving model ...
# Epoch [81/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000341 --> 0.000341).  Saving model ...
# Epoch [82/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [83/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000341 --> 0.000338).  Saving model ...
# Epoch [84/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000338 --> 0.000331).  Saving model ...
# Epoch [85/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000331 --> 0.000327).  Saving model ...
# Epoch [86/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [87/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000327 --> 0.000327).  Saving model ...
# Epoch [88/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000327 --> 0.000315).  Saving model ...
# Epoch [89/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [90/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 2 out of 20
# Epoch [91/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 3 out of 20
# Epoch [92/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 4 out of 20
# Epoch [93/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 5 out of 20
# Epoch [94/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000315 --> 0.000308).  Saving model ...
# Epoch [95/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000308 --> 0.000306).  Saving model ...
# Epoch [96/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [97/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000306 --> 0.000299).  Saving model ...
# Epoch [98/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000299 --> 0.000298).  Saving model ...
# Epoch [99/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [100/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 2 out of 20
# Epoch [101/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 3 out of 20
# Epoch [102/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 4 out of 20
# Epoch [103/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000298 --> 0.000292).  Saving model ...
# Epoch [104/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [105/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000292 --> 0.000289).  Saving model ...
# Epoch [106/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000289 --> 0.000278).  Saving model ...
# Epoch [107/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [108/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 2 out of 20
# Epoch [109/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 3 out of 20
# Epoch [110/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 4 out of 20
# Epoch [111/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 5 out of 20
# Epoch [112/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 6 out of 20
# Epoch [113/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 7 out of 20
# Epoch [114/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000278 --> 0.000277).  Saving model ...
# Epoch [115/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000277 --> 0.000270).  Saving model ...
# Epoch [116/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [117/10000], Train Loss: 0.0003, Val Loss: 0.0003
# Validation loss decreased (0.000270 --> 0.000267).  Saving model ...
# Epoch [118/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 1 out of 20
# Epoch [119/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 2 out of 20
# Epoch [120/10000], Train Loss: 0.0002, Val Loss: 0.0003
# EarlyStopping counter: 3 out of 20
# Epoch [121/10000], Train Loss: 0.0002, Val Loss: 0.0003
# EarlyStopping counter: 4 out of 20
# Epoch [122/10000], Train Loss: 0.0002, Val Loss: 0.0003
# Validation loss decreased (0.000267 --> 0.000265).  Saving model ...
# Epoch [123/10000], Train Loss: 0.0002, Val Loss: 0.0003
# Validation loss decreased (0.000265 --> 0.000260).  Saving model ...
# Epoch [124/10000], Train Loss: 0.0002, Val Loss: 0.0003
# Validation loss decreased (0.000260 --> 0.000257).  Saving model ...
# Epoch [125/10000], Train Loss: 0.0002, Val Loss: 0.0003
# Validation loss decreased (0.000257 --> 0.000256).  Saving model ...
# Epoch [126/10000], Train Loss: 0.0002, Val Loss: 0.0003
# Validation loss decreased (0.000256 --> 0.000253).  Saving model ...
# Epoch [127/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000253 --> 0.000242).  Saving model ...
# Epoch [128/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [129/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 2 out of 20
# Epoch [130/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 3 out of 20
# Epoch [131/10000], Train Loss: 0.0003, Val Loss: 0.0003
# EarlyStopping counter: 4 out of 20
# Epoch [132/10000], Train Loss: 0.0002, Val Loss: 0.0003
# EarlyStopping counter: 5 out of 20
# Epoch [133/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000242 --> 0.000242).  Saving model ...
# Epoch [134/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000242 --> 0.000241).  Saving model ...
# Epoch [135/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [136/10000], Train Loss: 0.0002, Val Loss: 0.0003
# EarlyStopping counter: 2 out of 20
# Epoch [137/10000], Train Loss: 0.0002, Val Loss: 0.0003
# EarlyStopping counter: 3 out of 20
# Epoch [138/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [139/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 5 out of 20
# Epoch [140/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 6 out of 20
# Epoch [141/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 7 out of 20
# Epoch [142/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000241 --> 0.000230).  Saving model ...
# Epoch [143/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000230 --> 0.000229).  Saving model ...
# Epoch [144/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000229 --> 0.000227).  Saving model ...
# Epoch [145/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [146/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [147/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [148/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [149/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 5 out of 20
# Epoch [150/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000227 --> 0.000222).  Saving model ...
# Epoch [151/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [152/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [153/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000222 --> 0.000220).  Saving model ...
# Epoch [154/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [155/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [156/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [157/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [158/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000220 --> 0.000208).  Saving model ...
# Epoch [159/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000208 --> 0.000203).  Saving model ...
# Epoch [160/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000203 --> 0.000203).  Saving model ...
# Epoch [161/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [162/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [163/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [164/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [165/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 5 out of 20
# Epoch [166/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 6 out of 20
# Epoch [167/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 7 out of 20
# Epoch [168/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000203 --> 0.000199).  Saving model ...
# Epoch [169/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [170/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [171/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [172/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [173/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000199 --> 0.000195).  Saving model ...
# Epoch [174/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [175/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [176/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000195 --> 0.000193).  Saving model ...
# Epoch [177/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [178/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [179/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [180/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [181/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 5 out of 20
# Epoch [182/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 6 out of 20
# Epoch [183/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 7 out of 20
# Epoch [184/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 8 out of 20
# Epoch [185/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 9 out of 20
# Epoch [186/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 10 out of 20
# Epoch [187/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 11 out of 20
# Epoch [188/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000193 --> 0.000182).  Saving model ...
# Epoch [189/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [190/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [191/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [192/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [193/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 5 out of 20
# Epoch [194/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000182 --> 0.000182).  Saving model ...
# Epoch [195/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [196/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000182 --> 0.000181).  Saving model ...
# Epoch [197/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000181 --> 0.000180).  Saving model ...
# Epoch [198/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [199/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [200/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [201/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [202/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 5 out of 20
# Epoch [203/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 6 out of 20
# Epoch [204/10000], Train Loss: 0.0002, Val Loss: 0.0002
# Validation loss decreased (0.000180 --> 0.000179).  Saving model ...
# Epoch [205/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 1 out of 20
# Epoch [206/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 2 out of 20
# Epoch [207/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 3 out of 20
# Epoch [208/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 4 out of 20
# Epoch [209/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 5 out of 20
# Epoch [210/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 6 out of 20
# Epoch [211/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 7 out of 20
# Epoch [212/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 8 out of 20
# Epoch [213/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 9 out of 20
# Epoch [214/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 10 out of 20
# Epoch [215/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 11 out of 20
# Epoch [216/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 12 out of 20
# Epoch [217/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 13 out of 20
# Epoch [218/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 14 out of 20
# Epoch [219/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 15 out of 20
# Epoch [220/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 16 out of 20
# Epoch [221/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 17 out of 20
# Epoch [222/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 18 out of 20
# Epoch [223/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 19 out of 20
# Epoch [224/10000], Train Loss: 0.0002, Val Loss: 0.0002
# EarlyStopping counter: 20 out of 20
# Early stopping
# Best Validation Loss: 0.0002
